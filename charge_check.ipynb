# %%
import uproot
import matplotlib.pyplot as plt
import pandas as pd
import mplhep
import boost_histogram as bh
import glob
from tqdm import tqdm
import numpy as np

# %%
# data = uproot.open("build/17230.root")
# histograms = data["histograms"]

# %%
# for hist_name, hist in histograms.items():

#     h = hist.to_boost()
#     fig, ax = plt.subplots()
#     mplhep.histplot(h, ax=ax, flow='none', label=hist_name)
#     ax.set_title(hist_name)

#     # underflow = h[bh.underflow]
#     underflow = h[0]
#     print(f"Underflow for {hist_name}: {underflow}")
#     ax.set_yscale('log')

#     print(h)

# %%
filelist = sorted(glob.glob("AnalysisZipFramework/submission/analysis_output-BadReducedCharge/*.root"))

h_2022 = None
h_2023 = None
h_2024_preCaloNu = None
h_2024_withCaloNu = None
h_2024_postCaloNu = None

for fpath in tqdm(filelist):
    data = uproot.open(fpath)
    histograms = data["histograms"]
    meta = data["meta"]

    lumi = meta["lumi"].array()[0]
    run_number = int(fpath.split("/")[-1].split(".")[0].split("_")[-1])

    h = histograms["VetoNu0_reduced_charge"].to_boost()

    if len(lumi) == 0:
        continue
    else:
        lumi = lumi[0]

    h = h / lumi    
    if run_number < 1e4:
        print(f"Adding run {run_number} to 2022")
        if h_2022 is None:
            h_2022 = h
        else:
            h_2022 += h
    elif run_number < 1.2e4:
        print(f"Adding run {run_number} to 2023")
        if h_2023 is None:
            h_2023 = h
        else:
            h_2023 += h
    
    elif run_number < 15821: # 2024_preCaloNu
        print(f"Adding run {run_number} to 2024_preCaloNu")
        if h_2024_preCaloNu is None:
            h_2024_preCaloNu = h
        else:
            h_2024_preCaloNu += h
    
    elif 15821 < run_number < 16924: # 2024_CaloNu
        print(f"Adding run {run_number} to 2024_withCaloNu")
        if h_2024_withCaloNu is None:
            h_2024_withCaloNu = h
        else:
            h_2024_withCaloNu += h

    elif run_number > 16924: # 2024_afterCaloNu
        print(f"Adding run {run_number} to 2024_postCaloNu")
        if h_2024_postCaloNu is None:
            h_2024_postCaloNu = h
        else:
            h_2024_postCaloNu += h
# Out:
#   0%|          | 0/276 [00:00<?, ?it/s]
#  11%|█         | 31/276 [00:00<00:02, 87.06it/s]
# Adding run 14593 to 2024_preCaloNu
# Adding run 14618 to 2024_preCaloNu
# Adding run 14644 to 2024_preCaloNu
# Adding run 14645 to 2024_preCaloNu
# Adding run 14647 to 2024_preCaloNu
# Adding run 14743 to 2024_preCaloNu
# Adding run 14758 to 2024_preCaloNu
# Adding run 14760 to 2024_preCaloNu
# Adding run 14763 to 2024_preCaloNu
# Adding run 14764 to 2024_preCaloNu
# Adding run 14765 to 2024_preCaloNu
# Adding run 14767 to 2024_preCaloNu
# Adding run 14769 to 2024_preCaloNu
# Adding run 14771 to 2024_preCaloNu
# Adding run 14777 to 2024_preCaloNu
# Adding run 14797 to 2024_preCaloNu
# Adding run 14799 to 2024_preCaloNu
# Adding run 14804 to 2024_preCaloNu
# Adding run 14809 to 2024_preCaloNu
# Adding run 14810 to 2024_preCaloNu
# Adding run 14904 to 2024_preCaloNu
# Adding run 14905 to 2024_preCaloNu
# Adding run 14906 to 2024_preCaloNu
# Adding run 14954 to 2024_preCaloNu
# Adding run 14971 to 2024_preCaloNu
# Adding run 14972 to 2024_preCaloNu
# Adding run 14973 to 2024_preCaloNu
#  24%|██▍       | 66/276 [00:00<00:01, 132.53it/s]
# Adding run 14974 to 2024_preCaloNu
# Adding run 14975 to 2024_preCaloNu
# Adding run 14976 to 2024_preCaloNu
# Adding run 14977 to 2024_preCaloNu
# Adding run 14980 to 2024_preCaloNu
# Adding run 14981 to 2024_preCaloNu
# Adding run 14985 to 2024_preCaloNu
# Adding run 14989 to 2024_preCaloNu
# Adding run 15007 to 2024_preCaloNu
# Adding run 15015 to 2024_preCaloNu
# Adding run 15016 to 2024_preCaloNu
# Adding run 15023 to 2024_preCaloNu
# Adding run 15024 to 2024_preCaloNu
# Adding run 15025 to 2024_preCaloNu
# Adding run 15031 to 2024_preCaloNu
# Adding run 15032 to 2024_preCaloNu
# Adding run 15034 to 2024_preCaloNu
# Adding run 15050 to 2024_preCaloNu
# Adding run 15051 to 2024_preCaloNu
# Adding run 15052 to 2024_preCaloNu
# Adding run 15055 to 2024_preCaloNu
# Adding run 15059 to 2024_preCaloNu
# Adding run 15269 to 2024_preCaloNu
# Adding run 15270 to 2024_preCaloNu
# Adding run 15287 to 2024_preCaloNu
# Adding run 15289 to 2024_preCaloNu
# Adding run 15290 to 2024_preCaloNu
# Adding run 15387 to 2024_preCaloNu
#  36%|███▌      | 100/276 [00:00<00:01, 150.67it/s]
# Adding run 15388 to 2024_preCaloNu
# Adding run 15390 to 2024_preCaloNu
# Adding run 15391 to 2024_preCaloNu
# Adding run 15394 to 2024_preCaloNu
# Adding run 15396 to 2024_preCaloNu
# Adding run 15398 to 2024_preCaloNu
# Adding run 15415 to 2024_preCaloNu
# Adding run 15418 to 2024_preCaloNu
# Adding run 15422 to 2024_preCaloNu
# Adding run 15424 to 2024_preCaloNu
# Adding run 15425 to 2024_preCaloNu
# Adding run 15429 to 2024_preCaloNu
# Adding run 15432 to 2024_preCaloNu
# Adding run 15434 to 2024_preCaloNu
# Adding run 15438 to 2024_preCaloNu
# Adding run 15439 to 2024_preCaloNu
# Adding run 15443 to 2024_preCaloNu
# Adding run 15445 to 2024_preCaloNu
# Adding run 15446 to 2024_preCaloNu
# Adding run 15681 to 2024_preCaloNu
# Adding run 15683 to 2024_preCaloNu
# Adding run 15685 to 2024_preCaloNu
# Adding run 15687 to 2024_preCaloNu
# Adding run 15688 to 2024_preCaloNu
# Adding run 15691 to 2024_preCaloNu
# Adding run 15723 to 2024_preCaloNu
# Adding run 15749 to 2024_preCaloNu
#  48%|████▊     | 132/276 [00:01<00:00, 152.78it/s]
# Adding run 15751 to 2024_preCaloNu
# Adding run 15754 to 2024_preCaloNu
# Adding run 15755 to 2024_preCaloNu
# Adding run 15758 to 2024_preCaloNu
# Adding run 15762 to 2024_preCaloNu
# Adding run 15763 to 2024_preCaloNu
# Adding run 15765 to 2024_preCaloNu
# Adding run 15766 to 2024_preCaloNu
# Adding run 15782 to 2024_preCaloNu
# Adding run 15784 to 2024_preCaloNu
# Adding run 15785 to 2024_preCaloNu
# Adding run 15786 to 2024_preCaloNu
# Adding run 15787 to 2024_preCaloNu
# Adding run 15789 to 2024_preCaloNu
# Adding run 15790 to 2024_preCaloNu
# Adding run 15814 to 2024_preCaloNu
# Adding run 15816 to 2024_preCaloNu
# Adding run 15818 to 2024_preCaloNu
# Adding run 15820 to 2024_preCaloNu
# Adding run 15838 to 2024_withCaloNu
# Adding run 15839 to 2024_withCaloNu
# Adding run 15844 to 2024_withCaloNu
# Adding run 15850 to 2024_withCaloNu
# Adding run 15874 to 2024_withCaloNu
# Adding run 15877 to 2024_withCaloNu
# Adding run 15878 to 2024_withCaloNu
# Adding run 15882 to 2024_withCaloNu
# Adding run 15883 to 2024_withCaloNu
#  60%|█████▉    | 165/276 [00:01<00:00, 156.00it/s]
# Adding run 15884 to 2024_withCaloNu
# Adding run 15902 to 2024_withCaloNu
# Adding run 15903 to 2024_withCaloNu
# Adding run 15909 to 2024_withCaloNu
# Adding run 15912 to 2024_withCaloNu
# Adding run 15913 to 2024_withCaloNu
# Adding run 15915 to 2024_withCaloNu
# Adding run 15917 to 2024_withCaloNu
# Adding run 15918 to 2024_withCaloNu
# Adding run 15919 to 2024_withCaloNu
# Adding run 15945 to 2024_withCaloNu
# Adding run 15946 to 2024_withCaloNu
# Adding run 15948 to 2024_withCaloNu
# Adding run 15949 to 2024_withCaloNu
# Adding run 15950 to 2024_withCaloNu
# Adding run 15951 to 2024_withCaloNu
# Adding run 15953 to 2024_withCaloNu
# Adding run 15955 to 2024_withCaloNu
# Adding run 15956 to 2024_withCaloNu
# Adding run 15957 to 2024_withCaloNu
# Adding run 15961 to 2024_withCaloNu
# Adding run 15963 to 2024_withCaloNu
# Adding run 15967 to 2024_withCaloNu
# Adding run 15994 to 2024_withCaloNu
# Adding run 15996 to 2024_withCaloNu
# Adding run 15998 to 2024_withCaloNu
# Adding run 16000 to 2024_withCaloNu
#  72%|███████▏  | 198/276 [00:01<00:00, 157.30it/s]
# Adding run 16001 to 2024_withCaloNu
# Adding run 16018 to 2024_withCaloNu
# Adding run 16022 to 2024_withCaloNu
# Adding run 16023 to 2024_withCaloNu
# Adding run 16024 to 2024_withCaloNu
# Adding run 16028 to 2024_withCaloNu
# Adding run 16042 to 2024_withCaloNu
# Adding run 16043 to 2024_withCaloNu
# Adding run 16057 to 2024_withCaloNu
# Adding run 16064 to 2024_withCaloNu
# Adding run 16065 to 2024_withCaloNu
# Adding run 16068 to 2024_withCaloNu
# Adding run 16071 to 2024_withCaloNu
# Adding run 16072 to 2024_withCaloNu
# Adding run 16073 to 2024_withCaloNu
# Adding run 16075 to 2024_withCaloNu
# Adding run 16077 to 2024_withCaloNu
# Adding run 16098 to 2024_withCaloNu
# Adding run 16099 to 2024_withCaloNu
# Adding run 16100 to 2024_withCaloNu
# Adding run 16102 to 2024_withCaloNu
# Adding run 16103 to 2024_withCaloNu
# Adding run 16393 to 2024_withCaloNu
# Adding run 16394 to 2024_withCaloNu
# Adding run 16396 to 2024_withCaloNu
# Adding run 16400 to 2024_withCaloNu
# Adding run 16403 to 2024_withCaloNu
# Adding run 16405 to 2024_withCaloNu
#  84%|████████▍ | 233/276 [00:01<00:00, 162.86it/s]
# Adding run 16523 to 2024_withCaloNu
# Adding run 16531 to 2024_withCaloNu
# Adding run 16533 to 2024_withCaloNu
# Adding run 16542 to 2024_withCaloNu
# Adding run 16558 to 2024_withCaloNu
# Adding run 16564 to 2024_withCaloNu
# Adding run 16635 to 2024_withCaloNu
# Adding run 16649 to 2024_withCaloNu
# Adding run 16653 to 2024_withCaloNu
# Adding run 16657 to 2024_withCaloNu
# Adding run 16658 to 2024_withCaloNu
# Adding run 16660 to 2024_withCaloNu
# Adding run 16661 to 2024_withCaloNu
# Adding run 16662 to 2024_withCaloNu
# Adding run 16663 to 2024_withCaloNu
# Adding run 16665 to 2024_withCaloNu
# Adding run 16667 to 2024_withCaloNu
# Adding run 16685 to 2024_withCaloNu
# Adding run 16687 to 2024_withCaloNu
# Adding run 16693 to 2024_withCaloNu
# Adding run 16696 to 2024_withCaloNu
# Adding run 16697 to 2024_withCaloNu
# Adding run 16699 to 2024_withCaloNu
#  97%|█████████▋| 267/276 [00:01<00:00, 162.34it/s]
# Adding run 16715 to 2024_withCaloNu
# Adding run 16730 to 2024_withCaloNu
# Adding run 16731 to 2024_withCaloNu
# Adding run 16732 to 2024_withCaloNu
# Adding run 16798 to 2024_withCaloNu
# Adding run 16800 to 2024_withCaloNu
# Adding run 16802 to 2024_withCaloNu
# Adding run 16805 to 2024_withCaloNu
# Adding run 16806 to 2024_withCaloNu
# Adding run 16850 to 2024_withCaloNu
# Adding run 16853 to 2024_withCaloNu
# Adding run 16901 to 2024_withCaloNu
# Adding run 16916 to 2024_withCaloNu
# Adding run 16923 to 2024_withCaloNu
# Adding run 16929 to 2024_postCaloNu
# Adding run 16930 to 2024_postCaloNu
# Adding run 16931 to 2024_postCaloNu
# Adding run 16934 to 2024_postCaloNu
# Adding run 16937 to 2024_postCaloNu
# Adding run 16938 to 2024_postCaloNu
# Adding run 16939 to 2024_postCaloNu
# Adding run 16940 to 2024_postCaloNu
# Adding run 16941 to 2024_postCaloNu
# Adding run 16943 to 2024_postCaloNu
# Adding run 16974 to 2024_postCaloNu
# 100%|██████████| 276/276 [00:01<00:00, 139.93it/s]
# Adding run 17018 to 2024_postCaloNu
# Adding run 17023 to 2024_postCaloNu
# Adding run 17095 to 2024_postCaloNu
# Adding run 17102 to 2024_postCaloNu
# Adding run 17127 to 2024_postCaloNu
# Adding run 17147 to 2024_postCaloNu
# Adding run 17199 to 2024_postCaloNu
# Adding run 17230 to 2024_postCaloNu

# %%
fig, ax = plt.subplots()
# mplhep.histplot(h_2022, ax=ax, flow='none', label="2022", density=True)
# mplhep.histplot(h_2023, ax=ax, flow='none', label="2023", density=True)
mplhep.histplot(h_2024_preCaloNu, ax=ax, flow='none', label="2024 preCaloNu", density=True)
mplhep.histplot(h_2024_withCaloNu, ax=ax, flow='none', label="2024 withCaloNu", density=True)
mplhep.histplot(h_2024_postCaloNu, ax=ax, flow='none', label="2024 postCaloNu", density=True)
ax.set_title("VetoNu0_reduced_charge")
ax.set_yscale('log')
ax.legend()
ax.set_xlim(0, 2000)
ax.set_ylabel("Events (unit normalised)")
ax.set_xlabel("VetoNu0 reduced charge [pC]")
plt.savefig("VetoNu0_reduced_charge.png", dpi=300)
plt.savefig("VetoNu0_reduced_charge.pdf", dpi=300)

# %%
run_numbers = []
n_fail_events = []
n_fail_events_err = []

for fpath in tqdm(filelist):
    data = uproot.open(fpath)
    histograms = data["histograms"]
    meta = data["meta"]

    lumi = meta["lumi"].array()[0]
    run_number = int(fpath.split("/")[-1].split(".")[0].split("_")[-1])

    h = histograms["VetoNu0_reduced_charge"].to_boost()

    if len(lumi) == 0:
        continue
    else:
        lumi = lumi[0]

    if run_number < 1.2e4:
        continue
    
    run_numbers.append(run_number)
    n_fail_events.append(h[0] / lumi)
    n_fail_events_err.append(np.sqrt(h[0]) / lumi)
# Out:
# 100%|██████████| 276/276 [00:01<00:00, 173.24it/s]

# %%
fig, ax = plt.subplots()
ax.errorbar(run_numbers, n_fail_events, yerr=n_fail_events_err, fmt='o')
ax.axvline(x=15821, color='r', linestyle='--', label='CaloNu Start')
ax.axvline(x=16924, color='g', linestyle='--', label='CaloNu End')
ax.set_xlabel("Run Number")
ax.set_ylabel("Failed Events / pb")
ax.legend()
ax.set_title("2024 data: VetoNu0_reduced_charge == 0 && VetoNu0_raw_charge > 30", fontsize=8, loc='left')
# Out:
# Text(0.0, 1.0, '2024 data: VetoNu0_reduced_charge == 0 && VetoNu0_raw_charge > 30')

# %%
files_2024 = [f for f in filelist if int(f.split("/")[-1].split(".")[0].split("_")[-1]) > 1.2e4]
files_caloNu = [f for f in files_2024 if 15821 <= int(f.split("/")[-1].split(".")[0].split("_")[-1]) <= 16924]

# %%
d = uproot.open(files_caloNu[0])["nt"]
for key in d.keys():
    if "calonu" in key.lower():
        print(key)
# Out:
# CaloNu0_E_EM
# CaloNu0_E_dep
# CaloNu0_baseline
# CaloNu0_baseline_rms
# CaloNu0_bcidtime
# CaloNu0_charge
# CaloNu0_localtime
# CaloNu0_nMIP
# CaloNu0_peak
# CaloNu0_raw_charge
# CaloNu0_raw_peak
# CaloNu0_status
# CaloNu0_triggertime
# CaloNu0_width
# CaloNu1_E_EM
# CaloNu1_E_dep
# CaloNu1_baseline
# CaloNu1_baseline_rms
# CaloNu1_bcidtime
# CaloNu1_charge
# CaloNu1_localtime
# CaloNu1_nMIP
# CaloNu1_peak
# CaloNu1_raw_charge
# CaloNu1_raw_peak
# CaloNu1_status
# CaloNu1_triggertime
# CaloNu1_width
# CaloNu2_E_EM
# CaloNu2_E_dep
# CaloNu2_baseline
# CaloNu2_baseline_rms
# CaloNu2_bcidtime
# CaloNu2_charge
# CaloNu2_localtime
# CaloNu2_nMIP
# CaloNu2_peak
# CaloNu2_raw_charge
# CaloNu2_raw_peak
# CaloNu2_status
# CaloNu2_triggertime
# CaloNu2_width
# CaloNu3_E_EM
# CaloNu3_E_dep
# CaloNu3_baseline
# CaloNu3_baseline_rms
# CaloNu3_bcidtime
# CaloNu3_charge
# CaloNu3_localtime
# CaloNu3_nMIP
# CaloNu3_peak
# CaloNu3_raw_charge
# CaloNu3_raw_peak
# CaloNu3_status
# CaloNu3_triggertime
# CaloNu3_width
# CaloNu_total_E_EM
# CaloNu_total_E_dep
# CaloNu_total_fit_E_EM
# CaloNu_total_nMIP
# CaloNu_total_raw_E_EM
# caloNuStatusCleaning
# caloNuVeto2StatusBug
# caloNuVetoNuStatusKeep
# isCaloNuPeriod

# %%
h_caloNuEdep = bh.Histogram(bh.axis.Regular(50, 0, 100e3))
for f in tqdm(files_caloNu):
    d = uproot.open(f)["nt"]
    calonuEdep = d["CaloNu_total_E_EM"].array()
    h_caloNuEdep.fill(calonuEdep)
# Out:
# 100%|██████████| 130/130 [00:29<00:00,  4.47it/s]

# %%
print(h_caloNuEdep)
# Out:
#                        ┌─────────────────────────────────────────────────────┐
# [   -inf,       0) 0   │                                                     │
# [      0,    2000) 254 │████████████████████████████████████████████████████ │
# [   2000,    4000) 30  │██████▏                                              │
# [   4000,    6000) 8   │█▋                                                   │
# [   6000,    8000) 2   │▍                                                    │
# [   8000,   1e+04) 2   │▍                                                    │
# [  1e+04, 1.2e+04) 4   │▉                                                    │
# [1.2e+04, 1.4e+04) 2   │▍                                                    │
# [1.4e+04, 1.6e+04) 1   │▎                                                    │
# [1.6e+04, 1.8e+04) 0   │                                                     │
# [1.8e+04,   2e+04) 0   │                                                     │
# [  2e+04, 2.2e+04) 0   │                                                     │
# [2.2e+04, 2.4e+04) 0   │                                                     │
# [2.4e+04, 2.6e+04) 0   │                                                     │
# [2.6e+04, 2.8e+04) 0   │                                                     │
# [2.8e+04,   3e+04) 0   │                                                     │
# [  3e+04, 3.2e+04) 0   │                                                     │
# [3.2e+04, 3.4e+04) 0   │                                                     │
# [3.4e+04, 3.6e+04) 0   │                                                     │
# [3.6e+04, 3.8e+04) 0   │                                                     │
# [3.8e+04,   4e+04) 0   │                                                     │
# [  4e+04, 4.2e+04) 0   │                                                     │
# [4.2e+04, 4.4e+04) 0   │                                                     │
# [4.4e+04, 4.6e+04) 0   │                                                     │
# [4.6e+04, 4.8e+04) 0   │                                                     │
# [4.8e+04,   5e+04) 0   │                                                     │
# [  5e+04, 5.2e+04) 0   │                                                     │
# [5.2e+04, 5.4e+04) 0   │                                                     │
# [5.4e+04, 5.6e+04) 1   │▎                                                    │
# [5.6e+04, 5.8e+04) 0   │                                                     │
# [5.8e+04,   6e+04) 0   │                                                     │
# [  6e+04, 6.2e+04) 0   │                                                     │
# [6.2e+04, 6.4e+04) 0   │                                                     │
# [6.4e+04, 6.6e+04) 0   │                                                     │
# [6.6e+04, 6.8e+04) 0   │                                                     │
# [6.8e+04,   7e+04) 0   │                                                     │
# [  7e+04, 7.2e+04) 0   │                                                     │
# [7.2e+04, 7.4e+04) 0   │                                                     │
# [7.4e+04, 7.6e+04) 0   │                                                     │
# [7.6e+04, 7.8e+04) 0   │                                                     │
# [7.8e+04,   8e+04) 0   │                                                     │
# [  8e+04, 8.2e+04) 0   │                                                     │
# [8.2e+04, 8.4e+04) 0   │                                                     │
# [8.4e+04, 8.6e+04) 0   │                                                     │
# [8.6e+04, 8.8e+04) 0   │                                                     │
# [8.8e+04,   9e+04) 0   │                                                     │
# [  9e+04, 9.2e+04) 0   │                                                     │
# [9.2e+04, 9.4e+04) 0   │                                                     │
# [9.4e+04, 9.6e+04) 0   │                                                     │
# [9.6e+04, 9.8e+04) 0   │                                                     │
# [9.8e+04,   1e+05) 0   │                                                     │
# [  1e+05,     inf) 3   │▋                                                    │
#                        └─────────────────────────────────────────────────────┘

# %%
fig, ax = plt.subplots()
mplhep.histplot(h_caloNuEdep, ax=ax, flow='none', label="CaloNu Edep")
ax.set_title("CaloNu Total Edep", fontsize=8, loc='left')
ax.set_xlabel("CaloNu Edep")
ax.set_ylabel("Events")
# Out:
# Text(0, 0.5, 'Events')

# %%
mc_caloNu = ["build/200139.root:nt", "build/200140.root:nt", "build/200146.root:nt"]

# %%
h_caloNuEdep_MC = bh.Histogram(bh.axis.Regular(50, 0, 100e3))
h_caloNuEdep_vs_zpos = bh.Histogram(bh.axis.Regular(50, -3100, -1500), bh.axis.Regular(50, 0, 100e3))
for f in tqdm(mc_caloNu):
    d = uproot.open(f)
    
    calonuEdep = d["CaloNu_total_E_EM"].array()
    zpos = d["truth_dec_z"].array()
    h_caloNuEdep_MC.fill(calonuEdep)
    print(calonuEdep)

    h_caloNuEdep_vs_zpos.fill(zpos[:, 0], calonuEdep)

h_caloNuEdep_MC = h_caloNuEdep_MC * 70 / 10_000
# Out:
#  33%|███▎      | 1/3 [00:00<00:00,  2.05it/s]
# [0, 9.52e+03, 7.33e+03, 0, 0, 1.76e+04, ..., 0, 0, 7.75e+03, 2.26e+04, 0]
#  67%|██████▋   | 2/3 [00:00<00:00,  2.17it/s]
# [0, 6.17e+03, 9.14e+03, 0, 7.7e+03, 0, 0, ..., 0, 0, 0, 0, 8.52e+03, 7.38e+03]
# 100%|██████████| 3/3 [00:01<00:00,  2.56it/s]
# [8.02e+03, 0, 0, 0, 0, 8.19e+03, 7.03e+03, ..., 0, 0, 0, 0, 0, 7.14e+03]

# %%
from matplotlib.colors import LogNorm
fig, ax = plt.subplots()
mplhep.hist2dplot(h_caloNuEdep_vs_zpos, ax=ax, flow='show', cmap='viridis', norm=LogNorm())
ax.set_xlabel("Truth neutrino vertex z [mm]")
ax.set_ylabel("CaloNu_total_E_EM [MeV]")
# Out:
# Text(12.097222222222216, 0.5, 'CaloNu_total_E_EM [MeV]')

# %%
fig, ax = plt.subplots()
mplhep.histplot(h_caloNuEdep_MC, ax=ax, flow='show', label="MC CaloNu Edep", histtype='fill')
mplhep.histplot(h_caloNuEdep, ax=ax, flow='show', label="Data CaloNu Edep", histtype='errorbar')
ax.set_title("MC CaloNu Total Edep", fontsize=8, loc='left')
ax.set_xlabel("CaloNu Edep")
ax.set_ylabel("Events")
ax.set_yscale('log')

# %%
print(f"MC CaloNu Edep sum (with flow): {h_caloNuEdep_MC.sum(flow=True)}")
print(f"Data CaloNu Edep sum (with flow): {h_caloNuEdep.sum(flow=True)}")
# Out:
# MC CaloNu Edep sum (with flow): 8644.265
# Data CaloNu Edep sum (with flow): 307.0

# %%
data_200146 = uproot.open("build/200146.root")["nt"]

for k in data_200146.keys():

    if "baseline" in k.lower():
        print(f'"{k}",')
# Out:
# "Calo0_baseline",
# "Calo0_baseline_rms",
# "Calo1_baseline",
# "Calo1_baseline_rms",
# "Calo2_baseline",
# "Calo2_baseline_rms",
# "Calo3_baseline",
# "Calo3_baseline_rms",
# "CaloNu0_baseline",
# "CaloNu0_baseline_rms",
# "CaloNu1_baseline",
# "CaloNu1_baseline_rms",
# "CaloNu2_baseline",
# "CaloNu2_baseline_rms",
# "CaloNu3_baseline",
# "CaloNu3_baseline_rms",
# "Preshower0_baseline",
# "Preshower0_baseline_rms",
# "Preshower1_baseline",
# "Preshower1_baseline_rms",
# "Timing0_baseline",
# "Timing0_baseline_rms",
# "Timing1_baseline",
# "Timing1_baseline_rms",
# "Timing2_baseline",
# "Timing2_baseline_rms",
# "Timing3_baseline",
# "Timing3_baseline_rms",
# "Veto10_baseline",
# "Veto10_baseline_rms",
# "Veto20_baseline",
# "Veto20_baseline_rms",
# "Veto21_baseline",
# "Veto21_baseline_rms",
# "VetoNu0_baseline",
# "VetoNu0_baseline_rms",
# "VetoNu1_baseline",
# "VetoNu1_baseline_rms",

# %%
data_200140 = uproot.open("build/200140.root")["nt"]
data_200140.keys()
# Out:
# ---------------------------------------------------------------------------
# KeyInFileError                            Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 data_200140 = uproot.open("build/200140.root")["nt"]
#       2 data_200140.keys()
#
# File ~/miniconda3/envs/faser/lib/python3.12/site-packages/uproot/reading.py:2122, in ReadOnlyDirectory.__getitem__(self, where)
#    2119     return step
#    2121 else:
# -> 2122     return self.key(where).get()
#
# File ~/miniconda3/envs/faser/lib/python3.12/site-packages/uproot/reading.py:2064, in ReadOnlyDirectory.key(self, where)
#    2062     return last
#    2063 elif cycle is None:
# -> 2064     raise uproot.KeyInFileError(
#    2065         item, cycle="any", keys=self.keys(), file_path=self._file.file_path
#    2066     )
#    2067 else:
#    2068     raise uproot.KeyInFileError(
#    2069         item, cycle=cycle, keys=self.keys(), file_path=self._file.file_path
#    2070     )
#
# KeyInFileError: not found: 'nt' (with any cycle number)
#
#     Available keys: (none!)
#
# in file build/200140.root

# %%
data_200139 = uproot.open("build/200139.root")["nt"]
data_200139.keys()
# Out:
# ---------------------------------------------------------------------------
# KeyInFileError                            Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 data_200139 = uproot.open("build/200139.root")["nt"]
#       2 data_200139.keys()
#
# File ~/miniconda3/envs/faser/lib/python3.12/site-packages/uproot/reading.py:2122, in ReadOnlyDirectory.__getitem__(self, where)
#    2119     return step
#    2121 else:
# -> 2122     return self.key(where).get()
#
# File ~/miniconda3/envs/faser/lib/python3.12/site-packages/uproot/reading.py:2064, in ReadOnlyDirectory.key(self, where)
#    2062     return last
#    2063 elif cycle is None:
# -> 2064     raise uproot.KeyInFileError(
#    2065         item, cycle="any", keys=self.keys(), file_path=self._file.file_path
#    2066     )
#    2067 else:
#    2068     raise uproot.KeyInFileError(
#    2069         item, cycle=cycle, keys=self.keys(), file_path=self._file.file_path
#    2070     )
#
# KeyInFileError: not found: 'nt' (with any cycle number)
#
#     Available keys: (none!)
#
# in file build/200139.root

# %%
[
 'Calo0_E_EM',
 'Calo0_E_dep',
 'Calo0_bcidtime',
 'Calo0_charge',
 'Calo0_localtime',
 'Calo0_nMIP',
 'Calo0_peak',
 'Calo0_raw_charge',
 'Calo0_raw_peak',
 'Calo0_status',
 'Calo0_triggertime',
 'Calo0_width',
 'Calo1_E_EM',
 'Calo1_E_dep',
 'Calo1_bcidtime',
 'Calo1_charge',
 'Calo1_localtime',
 'Calo1_nMIP',
 'Calo1_peak',
 'Calo1_raw_charge',
 'Calo1_raw_peak',
 'Calo1_status',
 'Calo1_triggertime',
 'Calo1_width',
 'Calo2_E_EM',
 'Calo2_E_dep',
 'Calo2_bcidtime',
 'Calo2_charge',
 'Calo2_localtime',
 'Calo2_nMIP',
 'Calo2_peak',
 'Calo2_raw_charge',
 'Calo2_raw_peak',
 'Calo2_status',
 'Calo2_triggertime',
 'Calo2_width',
 'Calo3_E_EM',
 'Calo3_E_dep',
 'Calo3_baseline',
 'Calo3_baseline_rms',
 'Calo3_bcidtime',
 'Calo3_charge',
 'Calo3_localtime',
 'Calo3_nMIP',
 'Calo3_peak',
 'Calo3_raw_charge',
 'Calo3_raw_peak',
 'Calo3_status',
 'Calo3_triggertime',
 'Calo3_width',
 'CaloNu0_E_EM',
 'CaloNu0_E_dep',
 'CaloNu0_baseline',
 'CaloNu0_baseline_rms',
 'CaloNu0_bcidtime',
 'CaloNu0_charge',
 'CaloNu0_localtime',
 'CaloNu0_nMIP',
 'CaloNu0_peak',
 'CaloNu0_raw_charge',
 'CaloNu0_raw_peak',
 'CaloNu0_status',
 'CaloNu0_triggertime',
 'CaloNu0_width',
 'CaloNu1_E_EM',
 'CaloNu1_E_dep',
 'CaloNu1_baseline',
 'CaloNu1_baseline_rms',
 'CaloNu1_bcidtime',
 'CaloNu1_charge',
 'CaloNu1_localtime',
 'CaloNu1_nMIP',
 'CaloNu1_peak',
 'CaloNu1_raw_charge',
 'CaloNu1_raw_peak',
 'CaloNu1_status',
 'CaloNu1_triggertime',
 'CaloNu1_width',
 'CaloNu2_E_EM',
 'CaloNu2_E_dep',
 'CaloNu2_baseline',
 'CaloNu2_baseline_rms',
 'CaloNu2_bcidtime',
 'CaloNu2_charge',
 'CaloNu2_localtime',
 'CaloNu2_nMIP',
 'CaloNu2_peak',
 'CaloNu2_raw_charge',
 'CaloNu2_raw_peak',
 'CaloNu2_status',
 'CaloNu2_triggertime',
 'CaloNu2_width',
 'CaloNu3_E_EM',
 'CaloNu3_E_dep',
 'CaloNu3_baseline',
 'CaloNu3_baseline_rms',
 'CaloNu3_bcidtime',
 'CaloNu3_charge',
 'CaloNu3_localtime',
 'CaloNu3_nMIP',
 'CaloNu3_peak',
 'CaloNu3_raw_charge',
 'CaloNu3_raw_peak',
 'CaloNu3_status',
 'CaloNu3_triggertime',
 'CaloNu3_width',
 'CaloNu_total_E_EM',
 'CaloNu_total_E_dep',
 'CaloNu_total_fit_E_EM',
 'CaloNu_total_nMIP',
 'CaloNu_total_raw_E_EM',
 'Calo_total_E_EM',
 'Calo_total_E_EM_fudged',
 'Calo_total_E_dep',
 'Calo_total_fit_E_EM',
 'Calo_total_fit_E_EM_fudged',
 'Calo_total_nMIP',
 'Calo_total_raw_E_EM',
 'Calo_total_raw_E_EM_fudged',
 'LeadTrack_Chi2',
 'LeadTrack_Chi2_NDF',
 'LeadTrack_Idx',
 'LeadTrack_Theta',
 'LeadTrack_nDoF',
 'LeadTrack_nLayers',
 'LeadTrack_pz0',
 'LeadTrack_rIFT',
 'LeadTrack_rVetoNu',
 'LeadTrack_r_atMaxRadius',
 'Preshower0_E_EM',
 'Preshower0_E_dep',
 'Preshower0_baseline',
 'Preshower0_baseline_rms',
 'Preshower0_bcidtime',
 'Preshower0_charge',
 'Preshower0_localtime',
 'Preshower0_nMIP',
 'Preshower0_peak',
 'Preshower0_raw_charge',
 'Preshower0_raw_peak',
 'Preshower0_status',
 'Preshower0_triggertime',
 'Preshower0_width',
 'Preshower1_E_EM',
 'Preshower1_E_dep',
 'Preshower1_baseline',
 'Preshower1_baseline_rms',
 'Preshower1_bcidtime',
 'Preshower1_charge',
 'Preshower1_localtime',
 'Preshower1_nMIP',
 'Preshower1_peak',
 'Preshower1_raw_charge',
 'Preshower1_raw_peak',
 'Preshower1_status',
 'Preshower1_triggertime',
 'Preshower1_width',
 'Preshower_total_E_dep',
 'Preshower_total_nMIP',
 'Timing0_baseline',
 'Timing0_baseline_rms',
 'Timing0_bcidtime',
 'Timing0_charge',
 'Timing0_localtime',
 'Timing0_peak',
 'Timing0_raw_charge',
 'Timing0_raw_peak',
 'Timing0_status',
 'Timing0_triggertime',
 'Timing0_width',
 'Timing1_baseline',
 'Timing1_baseline_rms',
 'Timing1_bcidtime',
 'Timing1_charge',
 'Timing1_localtime',
 'Timing1_peak',
 'Timing1_raw_charge',
 'Timing1_raw_peak',
 'Timing1_status',
 'Timing1_triggertime',
 'Timing1_width',
 'Timing2_baseline',
 'Timing2_baseline_rms',
 'Timing2_bcidtime',
 'Timing2_charge',
 'Timing2_localtime',
 'Timing2_peak',
 'Timing2_raw_charge',
 'Timing2_raw_peak',
 'Timing2_status',
 'Timing2_triggertime',
 'Timing2_width',
 'Timing3_baseline',
 'Timing3_baseline_rms',
 'Timing3_bcidtime',
 'Timing3_charge',
 'Timing3_localtime',
 'Timing3_peak',
 'Timing3_raw_charge',
 'Timing3_raw_peak',
 'Timing3_status',
 'Timing3_triggertime',
 'Timing3_width',
 'Timing_charge_bottom',
 'Timing_charge_top',
 'Timing_charge_total',
 'TrackSegment_Chi2',
 'TrackSegment_nDoF',
 'TrackSegment_px',
 'TrackSegment_py',
 'TrackSegment_pz',
 'TrackSegment_x',
 'TrackSegment_y',
 'TrackSegment_z',
 'TrackSegments',
 'Track_Chi2',
 'Track_InStation0',
 'Track_InStation1',
 'Track_InStation2',
 'Track_InStation3',
 'Track_PropagationError',
 'Track_Theta',
 'Track_ThetaX_atCalo',
 'Track_ThetaX_atPreshower1',
 'Track_ThetaX_atPreshower2',
 'Track_ThetaX_atTrig',
 'Track_ThetaX_atVetoNu',
 'Track_ThetaX_atVetoStation1',
 'Track_ThetaX_atVetoStation2',
 'Track_ThetaY_atCalo',
 'Track_ThetaY_atPreshower1',
 'Track_ThetaY_atPreshower2',
 'Track_ThetaY_atTrig',
 'Track_ThetaY_atVetoNu',
 'Track_ThetaY_atVetoStation1',
 'Track_ThetaY_atVetoStation2',
 'Track_X_atCalo',
 'Track_X_atPreshower1',
 'Track_X_atPreshower2',
 'Track_X_atTrig',
 'Track_X_atVetoNu',
 'Track_X_atVetoStation1',
 'Track_X_atVetoStation2',
 'Track_Y_atCalo',
 'Track_Y_atPreshower1',
 'Track_Y_atPreshower2',
 'Track_Y_atTrig',
 'Track_Y_atVetoNu',
 'Track_Y_atVetoStation1',
 'Track_Y_atVetoStation2',
 'Track_charge',
 'Track_hitSet',
 'Track_module_eta0',
 'Track_module_phi0',
 'Track_nDoF',
 'Track_nLayers',
 'Track_p0',
 'Track_p1',
 'Track_px0',
 'Track_px1',
 'Track_py0',
 'Track_py1',
 'Track_pz0',
 'Track_pz1',
 'Track_rIFT',
 'Track_rVetoNu',
 'Track_rVetoStation1',
 'Track_rVetoStation2',
 'Track_r_atMaxRadius',
 'Track_x0',
 'Track_x1',
 'Track_x_atMaxRadius',
 'Track_y0',
 'Track_y1',
 'Track_y_atMaxRadius',
 'Track_z0',
 'Track_z1',
 'Track_z_atMaxRadius',
 'Veto10_baseline',
 'Veto10_baseline_rms',
 'Veto10_bcidtime',
 'Veto10_charge',
 'Veto10_localtime',
 'Veto10_peak',
 'Veto10_raw_charge',
 'Veto10_raw_peak',
 'Veto10_status',
 'Veto10_triggertime',
 'Veto10_width',
 'Veto20_baseline',
 'Veto20_baseline_rms',
 'Veto20_bcidtime',
 'Veto20_charge',
 'Veto20_localtime',
 'Veto20_peak',
 'Veto20_raw_charge',
 'Veto20_raw_peak',
 'Veto20_status',
 'Veto20_triggertime',
 'Veto20_width',
 'Veto21_baseline',
 'Veto21_baseline_rms',
 'Veto21_bcidtime',
 'Veto21_charge',
 'Veto21_localtime',
 'Veto21_peak',
 'Veto21_raw_charge',
 'Veto21_raw_peak',
 'Veto21_status',
 'Veto21_triggertime',
 'Veto21_width',
 'VetoNu0_baseline',
 'VetoNu0_baseline_rms',
 'VetoNu0_bcidtime',
 'VetoNu0_charge',
 'VetoNu0_localtime',
 'VetoNu0_peak',
 'VetoNu0_raw_charge',
 'VetoNu0_raw_peak',
 'VetoNu0_reduced_charge',
 'VetoNu0_status',
 'VetoNu0_triggertime',
 'VetoNu0_width',
 'VetoNu1_baseline',
 'VetoNu1_baseline_rms',
 'VetoNu1_bcidtime',
 'VetoNu1_charge',
 'VetoNu1_localtime',
 'VetoNu1_peak',
 'VetoNu1_raw_charge',
 'VetoNu1_raw_peak',
 'VetoNu1_reduced_charge',
 'VetoNu1_status',
 'VetoNu1_triggertime',
 'VetoNu1_width',
 'eventID',
 'inCaloNuPMT',
 'inFaserNuBox',
 'inLeadBlock',
 'isCaloNuPeriod',
 'isVerticalCrossingAngle',
 'longTracks',
 'run',
 'truthBarcode',
 'truthM_P',
 'truthM_px',
 'truthM_py',
 'truthM_pz',
 'truthM_x',
 'truthM_y',
 'truthM_z',
 'truthParticleBarcode',
 'truthParticleIsFiducial',
 'truthParticleMatchedTracks',
 'truthPdg',
 'truth_P',
 'truth_dec_r',
 'truth_dec_x',
 'truth_dec_y',
 'truth_dec_z',
 'truth_isFiducial',
 'truth_m',
 'truth_pdg',
 'truth_prod_x',
 'truth_prod_y',
 'truth_prod_z',
 'truth_px',
 'truth_py',
 'truth_pz',
 'truth_st0_px',
 'truth_st0_py',
 'truth_st0_pz',
 'truth_st0_x',
 'truth_st0_y',
 'truth_st0_z',
 'truth_st1_px',
 'truth_st1_py',
 'truth_st1_pz',
 'truth_st1_x',
 'truth_st1_y',
 'truth_st1_z',
 'truth_st2_px',
 'truth_st2_py',
 'truth_st2_pz',
 'truth_st2_x',
 'truth_st2_y',
 'truth_st2_z',
 'truth_st3_px',
 'truth_st3_py',
 'truth_st3_pz',
 'truth_st3_x',
 'truth_st3_y',
 'truth_st3_z',
 'vertex_chi2',
 'vertex_p0',
 'vertex_p1',
 'vertex_px0',
 'vertex_px1',
 'vertex_py0',
 'vertex_py1',
 'vertex_pz0',
 'vertex_pz1',
 'vertex_x',
 'vertex_y',
 'vertex_z']

# %%
data1 = uproot.open("/home/ppd/bewilson/work/nuAnalysis/AnalysisZipFramework/submission/analysis_output/8186.root")["nt"]
print(data1.keys())
# Out:
# ['AuxLookupSuccess', 'BCID', 'BadVetoStatus', 'Calo0_E_EM', 'Calo0_E_dep', 'Calo0_baseline', 'Calo0_baseline_rms', 'Calo0_bcidtime', 'Calo0_charge', 'Calo0_localtime', 'Calo0_nMIP', 'Calo0_peak', 'Calo0_raw_charge', 'Calo0_raw_peak', 'Calo0_status', 'Calo0_triggertime', 'Calo0_width', 'Calo1_E_EM', 'Calo1_E_dep', 'Calo1_baseline', 'Calo1_baseline_rms', 'Calo1_bcidtime', 'Calo1_charge', 'Calo1_localtime', 'Calo1_nMIP', 'Calo1_peak', 'Calo1_raw_charge', 'Calo1_raw_peak', 'Calo1_status', 'Calo1_triggertime', 'Calo1_width', 'Calo2_E_EM', 'Calo2_E_dep', 'Calo2_baseline', 'Calo2_baseline_rms', 'Calo2_bcidtime', 'Calo2_charge', 'Calo2_localtime', 'Calo2_nMIP', 'Calo2_peak', 'Calo2_raw_charge', 'Calo2_raw_peak', 'Calo2_status', 'Calo2_triggertime', 'Calo2_width', 'Calo3_E_EM', 'Calo3_E_dep', 'Calo3_baseline', 'Calo3_baseline_rms', 'Calo3_bcidtime', 'Calo3_charge', 'Calo3_localtime', 'Calo3_nMIP', 'Calo3_peak', 'Calo3_raw_charge', 'Calo3_raw_peak', 'Calo3_status', 'Calo3_triggertime', 'Calo3_width', 'Calo_total_E_EM', 'Calo_total_E_EM_fudged', 'Calo_total_E_dep', 'Calo_total_fit_E_EM', 'Calo_total_fit_E_EM_fudged', 'Calo_total_nMIP', 'Calo_total_raw_E_EM', 'Calo_total_raw_E_EM_fudged', 'CrossSection', 'ExcludedTimes', 'GenWeights', 'GoodPreshower0Hit', 'GoodPreshower1Hit', 'GoodScintillatorStatus', 'GoodTimes', 'GoodVeto20Hit', 'GoodVeto21Hit', 'GoodVetoNuStatus', 'LeadTrack_Chi2', 'LeadTrack_Chi2_NDF', 'LeadTrack_Idx', 'LeadTrack_Theta', 'LeadTrack_nDoF', 'LeadTrack_nLayers', 'LeadTrack_pz0', 'LeadTrack_rIFT', 'LeadTrack_rVetoNu', 'LeadTrack_r_atMaxRadius', 'Preshower0_E_EM', 'Preshower0_E_dep', 'Preshower0_baseline', 'Preshower0_baseline_rms', 'Preshower0_bcidtime', 'Preshower0_charge', 'Preshower0_localtime', 'Preshower0_nMIP', 'Preshower0_peak', 'Preshower0_raw_charge', 'Preshower0_raw_peak', 'Preshower0_status', 'Preshower0_triggertime', 'Preshower0_width', 'Preshower1_E_EM', 'Preshower1_E_dep', 'Preshower1_baseline', 'Preshower1_baseline_rms', 'Preshower1_bcidtime', 'Preshower1_charge', 'Preshower1_localtime', 'Preshower1_nMIP', 'Preshower1_peak', 'Preshower1_raw_charge', 'Preshower1_raw_peak', 'Preshower1_status', 'Preshower1_triggertime', 'Preshower1_width', 'Preshower_total_E_dep', 'Preshower_total_nMIP', 'ScintHit', 'SpacePoint_x', 'SpacePoint_y', 'SpacePoint_z', 'SpacePoints', 'TAP', 'TBP', 'Timing0_baseline', 'Timing0_baseline_rms', 'Timing0_bcidtime', 'Timing0_charge', 'Timing0_localtime', 'Timing0_peak', 'Timing0_raw_charge', 'Timing0_raw_peak', 'Timing0_status', 'Timing0_triggertime', 'Timing0_width', 'Timing1_baseline', 'Timing1_baseline_rms', 'Timing1_bcidtime', 'Timing1_charge', 'Timing1_localtime', 'Timing1_peak', 'Timing1_raw_charge', 'Timing1_raw_peak', 'Timing1_status', 'Timing1_triggertime', 'Timing1_width', 'Timing2_baseline', 'Timing2_baseline_rms', 'Timing2_bcidtime', 'Timing2_charge', 'Timing2_localtime', 'Timing2_peak', 'Timing2_raw_charge', 'Timing2_raw_peak', 'Timing2_status', 'Timing2_triggertime', 'Timing2_width', 'Timing3_baseline', 'Timing3_baseline_rms', 'Timing3_bcidtime', 'Timing3_charge', 'Timing3_localtime', 'Timing3_peak', 'Timing3_raw_charge', 'Timing3_raw_peak', 'Timing3_status', 'Timing3_triggertime', 'Timing3_width', 'TimingOK', 'Timing_charge_bottom', 'Timing_charge_top', 'Timing_charge_total', 'TrackSegment_Chi2', 'TrackSegment_nDoF', 'TrackSegment_px', 'TrackSegment_py', 'TrackSegment_pz', 'TrackSegment_x', 'TrackSegment_y', 'TrackSegment_z', 'TrackSegments', 'Track_Chi2', 'Track_InStation0', 'Track_InStation1', 'Track_InStation2', 'Track_InStation3', 'Track_PropagationError', 'Track_Theta', 'Track_ThetaX_atCalo', 'Track_ThetaX_atPreshower1', 'Track_ThetaX_atPreshower2', 'Track_ThetaX_atTrig', 'Track_ThetaX_atVetoNu', 'Track_ThetaX_atVetoStation1', 'Track_ThetaX_atVetoStation2', 'Track_ThetaY_atCalo', 'Track_ThetaY_atPreshower1', 'Track_ThetaY_atPreshower2', 'Track_ThetaY_atTrig', 'Track_ThetaY_atVetoNu', 'Track_ThetaY_atVetoStation1', 'Track_ThetaY_atVetoStation2', 'Track_X_atCalo', 'Trac ...
