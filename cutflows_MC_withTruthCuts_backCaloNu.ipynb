# %%
import uproot
import matplotlib.pyplot as plt
import pandas as pd
import tqdm
import numpy as np
import os
import glob
import awkward as ak
import boost_histogram as bh
import mplhep
# !pip install pyarrow
# !pip install "pyarrow<21" --break-system-packages

# %%
def get_cutflow_and_yields_for_run_range(files, mass=1.1):
    cutflow_dict = {}
    run_yields = {}

    run = os.path.basename(files[0]).split('.')[0]

    total_lumi = 0
    for fpath in tqdm.tqdm(files):

        with uproot.open(fpath) as f:
            tree = f["cutflow"]
            lumi = f["meta"].arrays(library="pd")["lumi"][0]
            df = tree.arrays(library="pd")

            total_lumi += lumi[0] / 1000 # /pb -> /fb
            for idx, row in df.iterrows():
                cut = row["cut_name"]
                all = row["all"]
                passed = row["passed"]
        
                if cut not in cutflow_dict:
                    cutflow_dict[cut] = {"all": 0, "passed": 0}
        
                cutflow_dict[cut]["all"] += all
                cutflow_dict[cut]["passed"] += passed
                cutflow_dict[cut]["efficiency"] = cutflow_dict[cut]["passed"] / cutflow_dict[cut]["all"] if cutflow_dict[cut]["all"] > 0 else 0
                cutflow_dict[cut]["cumulative_efficiency"] = cutflow_dict[cut]["passed"] / cutflow_dict[list(cutflow_dict.keys())[0]]["all"] if cutflow_dict[list(cutflow_dict.keys())[0]]["all"] > 0 else 0
                cutflow_dict[cut]["efficiency_error"] = np.sqrt(cutflow_dict[cut]["efficiency"] * (1 - cutflow_dict[cut]["efficiency"]) / cutflow_dict[cut]["all"]) if cutflow_dict[cut]["all"] > 0 else 0


                final_yield = np.amin(df["passed"])
                run_yields[run] = final_yield
                
    cutflow = pd.DataFrame.from_dict(cutflow_dict, orient="index")
    cutflow["rate [events/fb/tonne]"] = cutflow["passed"] / (total_lumi * mass) if total_lumi > 0 else 0
    cutflow = cutflow.sort_values(by='passed', ascending=False)
            
    return cutflow, run_yields

# %%
runs_F222 = [7733, 8712]
runs_F223 = [8713, 9188]

runs_F231 = [10555, 11470]
runs_F232 = [11470, 11703]

runs_F241 = [14399, 15026]
runs_tungsten = [15030, 15594]
runs_F242 = [15652, 15820]
runs_caloNu = [15821, 16924]
runs_F243 = [16928, 17230]

# %%
cutflow_F222, yields_F222 = get_cutflow_and_yields_for_run_range(["build/MC_truth_back_caloNu/2022_2023.bck.root"])
cutflow_F223, yields_F223 = get_cutflow_and_yields_for_run_range(["build/MC_truth_back_caloNu/2022_2023.bck.root"])
cutflow_F231, yields_F231 = get_cutflow_and_yields_for_run_range(["build/MC_truth_back_caloNu/2022_2023.bck.root"])
cutflow_F232, yields_F232 = get_cutflow_and_yields_for_run_range(["build/MC_truth_back_caloNu/2022_2023.bck.root"])
cutflow_F241, yields_F241         = get_cutflow_and_yields_for_run_range(["build/MC_truth_back_caloNu/2024_noCaloNu.bck.root"])
cutflow_tungsten, yields_tungsten = get_cutflow_and_yields_for_run_range(["build/MC_truth_back_caloNu/2024_noCaloNu.bck.root"])
cutflow_F242, yields_F242         = get_cutflow_and_yields_for_run_range(["build/MC_truth_back_caloNu/2024_noCaloNu.bck.root"])
cutflow_caloNu, yields_caloNu     = get_cutflow_and_yields_for_run_range(["build/MC_truth_back_caloNu/2024_CaloNu.bck.root"], mass=0.68)
cutflow_F243, yields_F243         = get_cutflow_and_yields_for_run_range(["build/MC_truth_back_caloNu/2024_noCaloNu.bck.root"])
# Out:
# 100%|██████████| 1/1 [00:00<00:00, 34.91it/s]
# 100%|██████████| 1/1 [00:00<00:00, 45.89it/s]
# 100%|██████████| 1/1 [00:00<00:00, 49.89it/s]
# 100%|██████████| 1/1 [00:00<00:00, 51.91it/s]
# 100%|██████████| 1/1 [00:00<00:00, 48.60it/s]
# 100%|██████████| 1/1 [00:00<00:00, 50.39it/s]
# 100%|██████████| 1/1 [00:00<00:00, 49.45it/s]
# 100%|██████████| 1/1 [00:00<00:00, 47.12it/s]
# 100%|██████████| 1/1 [00:00<00:00, 44.53it/s]

# %%
print("Cutflow for F222:")
display(cutflow_F222)
print("\n")
print("Cutflow for F223:")
display(cutflow_F223)
print("\n")
print("Cutflow for F231:")
display(cutflow_F231)
print("\n")
print("Cutflow for F232:")
display(cutflow_F232)
print("\n")
print("Cutflow for F241:")
display(cutflow_F241)
print("\n")
print("Cutflow for Tungsten:")
display(cutflow_tungsten)
print("\n")
print("Cutflow for F242:")
display(cutflow_F242)
print("\n")
print("Cutflow for CaloNu:")
display(cutflow_caloNu)
print("\n")
print("Cutflow for F243:")
display(cutflow_F243)
# Out:
# Cutflow for F222:
#                                       all   passed  efficiency  \
# Remove CaloNu PMT region (truth)  1493362  1493362    1.000000
# CC events only                    1493362  1132078    0.758073
# nu_mu only                        1132078   940530    0.830800
# In Faser Nu Box or Lead Block      940530   137069    0.145736
# Truth dec r < 100 mm               137069    59060    0.430878
# Truth pz > 100 GeV                  59060    54666    0.925601
# At least one long track             54666    28329    0.518220
# Veto20 and Veto21 charge > 40 pC    28329    28312    0.999400
# Timing Station Charge > 20 pC       28312    28303    0.999682
# Preshower Charge > 2.5 pC           28303    28040    0.990708
# Track pz > 100 GeV                  28040    23496    0.837946
# Leading track has at >= 7 layers    23496    22974    0.977783
# Track nDoF >= 9                     22974    21748    0.946635
# Leading track has chi2/ndof < 15    21748    21741    0.999678
# Track R at max radius < 95 mm       21741    15615    0.718228
# Track R at IFT < 95 mm              15615    15267    0.977714
# Track rVetoNu < 120 mm              15267    15029    0.984411
# Leading track theta < 25 mrad       15029    14495    0.964469
# VetoNu0 reduced charge < 30 pC      14495    14452    0.997033
# VetoNu1 reduced charge < 30 pC      14452    14418    0.997647
#
#                                   cumulative_efficiency  efficiency_error  \
# Remove CaloNu PMT region (truth)               1.000000          0.000000
# CC events only                                 0.758073          0.000350
# nu_mu only                                     0.629807          0.000352
# In Faser Nu Box or Lead Block                  0.091786          0.000364
# Truth dec r < 100 mm                           0.039548          0.001338
# Truth pz > 100 GeV                             0.036606          0.001080
# At least one long track                        0.018970          0.002137
# Veto20 and Veto21 charge > 40 pC               0.018959          0.000145
# Timing Station Charge > 20 pC                  0.018953          0.000106
# Preshower Charge > 2.5 pC                      0.018776          0.000570
# Track pz > 100 GeV                             0.015734          0.002201
# Leading track has at >= 7 layers               0.015384          0.000962
# Track nDoF >= 9                                0.014563          0.001483
# Leading track has chi2/ndof < 15               0.014558          0.000122
# Track R at max radius < 95 mm                  0.010456          0.003051
# Track R at IFT < 95 mm                         0.010223          0.001181
# Track rVetoNu < 120 mm                         0.010064          0.001003
# Leading track theta < 25 mrad                  0.009706          0.001510
# VetoNu0 reduced charge < 30 pC                 0.009677          0.000452
# VetoNu1 reduced charge < 30 pC                 0.009655          0.000403
#
#                                   rate [events/fb/tonne]
# Remove CaloNu PMT region (truth)                       0
# CC events only                                         0
# nu_mu only                                             0
# In Faser Nu Box or Lead Block                          0
# Truth dec r < 100 mm                                   0
# Truth pz > 100 GeV                                     0
# At least one long track                                0
# Veto20 and Veto21 charge > 40 pC                       0
# Timing Station Charge > 20 pC                          0
# Preshower Charge > 2.5 pC                              0
# Track pz > 100 GeV                                     0
# Leading track has at >= 7 layers                       0
# Track nDoF >= 9                                        0
# Leading track has chi2/ndof < 15                       0
# Track R at max radius < 95 mm                          0
# Track R at IFT < 95 mm                                 0
# Track rVetoNu < 120 mm                                 0
# Leading track theta < 25 mrad                          0
# VetoNu0 reduced charge < 30 pC                         0
# VetoNu1 reduced charge < 30 pC                         0
# Cutflow for F223:
#                                       all   passed  efficiency  \
# Remove CaloNu PMT region (truth)  1493362  1493362    1.000000
# CC events only                    1493362  1132078    0.758073
# nu_mu only                        1132078   940530    0.830800
# In Faser Nu Box or Lead Block      940530   137069    0.145736
# Truth dec r < 100 mm               137069    59060    0.430878
# Truth pz > 100 GeV                  59060    54666    0.925601
# At least one long track             54666    28329    0.518220
# Veto20 and Veto21 charge > 40 pC    28329    28312    0.999400
# Timing Station Charge > 20 pC       28312    28303    0.999682
# Preshower Charge > 2.5 pC           28303    28040    0.990708
# Track pz > 100 GeV                  28040    23496    0.837946
# Leading track has at >= 7 layers    23496    22974    0.977783
# Track nDoF >= 9                     22974    21748    0.946635
# Leading track has chi2/ndof < 15    21748    21741    0.999678
# Track R at max radius < 95 mm       21741    15615    0.718228
# Track R at IFT < 95 mm              15615    15267    0.977714
# Track rVetoNu < 120 mm              15267    15029    0.984411
# Leading track theta < 25 mrad       15029    14495    0.964469
# VetoNu0 reduced charge < 30 pC      14495    14452    0.997033
# VetoNu1 reduced charge < 30 pC      14452    14418    0.997647
#
#                                   cumulative_efficiency  efficiency_error  \
# Remove CaloNu PMT region (truth)               1.000000          0.000000
# CC events only                                 0.758073          0.000350
# nu_mu only                                     0.629807          0.000352
# In Faser Nu Box or Lead Block                  0.091786          0.000364
# Truth dec r < 100 mm                           0.039548          0.001338
# Truth pz > 100 GeV                             0.036606          0.001080
# At least one long track                        0.018970          0.002137
# Veto20 and Veto21 charge > 40 pC               0.018959          0.000145
# Timing Station Charge > 20 pC                  0.018953          0.000106
# Preshower Charge > 2.5 pC                      0.018776          0.000570
# Track pz > 100 GeV                             0.015734          0.002201
# Leading track has at >= 7 layers               0.015384          0.000962
# Track nDoF >= 9                                0.014563          0.001483
# Leading track has chi2/ndof < 15               0.014558          0.000122
# Track R at max radius < 95 mm                  0.010456          0.003051
# Track R at IFT < 95 mm                         0.010223          0.001181
# Track rVetoNu < 120 mm                         0.010064          0.001003
# Leading track theta < 25 mrad                  0.009706          0.001510
# VetoNu0 reduced charge < 30 pC                 0.009677          0.000452
# VetoNu1 reduced charge < 30 pC                 0.009655          0.000403
#
#                                   rate [events/fb/tonne]
# Remove CaloNu PMT region (truth)                       0
# CC events only                                         0
# nu_mu only                                             0
# In Faser Nu Box or Lead Block                          0
# Truth dec r < 100 mm                                   0
# Truth pz > 100 GeV                                     0
# At least one long track                                0
# Veto20 and Veto21 charge > 40 pC                       0
# Timing Station Charge > 20 pC                          0
# Preshower Charge > 2.5 pC                              0
# Track pz > 100 GeV                                     0
# Leading track has at >= 7 layers                       0
# Track nDoF >= 9                                        0
# Leading track has chi2/ndof < 15                       0
# Track R at max radius < 95 mm                          0
# Track R at IFT < 95 mm                                 0
# Track rVetoNu < 120 mm                                 0
# Leading track theta < 25 mrad                          0
# VetoNu0 reduced charge < 30 pC                         0
# VetoNu1 reduced charge < 30 pC                         0
# Cutflow for F231:
#                                       all   passed  efficiency  \
# Remove CaloNu PMT region (truth)  1493362  1493362    1.000000
# CC events only                    1493362  1132078    0.758073
# nu_mu only                        1132078   940530    0.830800
# In Faser Nu Box or Lead Block      940530   137069    0.145736
# Truth dec r < 100 mm               137069    59060    0.430878
# Truth pz > 100 GeV                  59060    54666    0.925601
# At least one long track             54666    28329    0.518220
# Veto20 and Veto21 charge > 40 pC    28329    28312    0.999400
# Timing Station Charge > 20 pC       28312    28303    0.999682
# Preshower Charge > 2.5 pC           28303    28040    0.990708
# Track pz > 100 GeV                  28040    23496    0.837946
# Leading track has at >= 7 layers    23496    22974    0.977783
# Track nDoF >= 9                     22974    21748    0.946635
# Leading track has chi2/ndof < 15    21748    21741    0.999678
# Track R at max radius < 95 mm       21741    15615    0.718228
# Track R at IFT < 95 mm              15615    15267    0.977714
# Track rVetoNu < 120 mm              15267    15029    0.984411
# Leading track theta < 25 mrad       15029    14495    0.964469
# VetoNu0 reduced charge < 30 pC      14495    14452    0.997033
# VetoNu1 reduced charge < 30 pC      14452    14418    0.997647
#
#                                   cumulative_efficiency  efficiency_error  \
# Remove CaloNu PMT region (truth)               1.000000          0.000000
# CC events only                                 0.758073          0.000350
# nu_mu only                                     0.629807          0.000352
# In Faser Nu Box or Lead Block                  0.091786          0.000364
# Truth dec r < 100 mm                           0.039548          0.001338
# Truth pz > 100 GeV                             0.036606          0.001080
# At least one long track                        0.018970          0.002137
# Veto20 and Veto21 charge > 40 pC               0.018959          0.000145
# Timing Station Charge > 20 pC                  0.018953          0.000106
# Preshower Charge > 2.5 pC                      0.018776          0.000570
# Track pz > 100 GeV                             0.015734          0.002201
# Leading track has at >= 7 layers               0.015384          0.000962
# Track nDoF >= 9                                0.014563          0.001483
# Leading track has chi2/ndof < 15               0.014558          0.000122
# Track R at max radius < 95 mm                  0.010456          0.003051
# Track R at IFT < 95 mm                         0.010223          0.001181
# Track rVetoNu < 120 mm                         0.010064          0.001003
# Leading track theta < 25 mrad                  0.009706          0.001510
# VetoNu0 reduced charge < 30 pC                 0.009677          0.000452
# VetoNu1 reduced charge < 30 pC                 0.009655          0.000403
#
#                                   rate [events/fb/tonne]
# Remove CaloNu PMT region (truth)                       0
# CC events only                                         0
# nu_mu only                                             0
# In Faser Nu Box or Lead Block                          0
# Truth dec r < 100 mm                                   0
# Truth pz > 100 GeV                                     0
# At least one long track                                0
# Veto20 and Veto21 charge > 40 pC                       0
# Timing Station Charge > 20 pC                          0
# Preshower Charge > 2.5 pC                              0
# Track pz > 100 GeV                                     0
# Leading track has at >= 7 layers                       0
# Track nDoF >= 9                                        0
# Leading track has chi2/ndof < 15                       0
# Track R at max radius < 95 mm                          0
# Track R at IFT < 95 mm                                 0
# Track rVetoNu < 120 mm                                 0
# Leading track theta < 25 mrad                          0
# VetoNu0 reduced charge < 30 pC                         0
# VetoNu1 reduced charge < 30 pC                         0
# Cutflow for F232:
#                                       all   passed  efficiency  \
# Remove CaloNu PMT region (truth)  1493362  1493362    1.000000
# CC events only                    1493362  1132078    0.758073
# nu_mu only                        1132078   940530    0.830800
# In Faser Nu Box or Lead Block      940530   137069    0.145736
# Truth dec r < 100 mm               137069    59060    0.430878
# Truth pz > 100 GeV                  59060    54666    0.925601
# At least one long track             54666    28329    0.518220
# Veto20 and Veto21 charge > 40 pC    28329    28312    0.999400
# Timing Station Charge > 20 pC       28312    28303    0.999682
# Preshower Charge > 2.5 pC           28303    28040    0.990708
# Track pz > 100 GeV                  28040    23496    0.837946
# Leading track has at >= 7 layers    23496    22974    0.977783
# Track nDoF >= 9                     22974    21748    0.946635
# Leading track has chi2/ndof < 15    21748    21741    0.999678
# Track R at max radius < 95 mm       21741    15615    0.718228
# Track R at IFT < 95 mm              15615    15267    0.977714
# Track rVetoNu < 120 mm              15267    15029    0.984411
# Leading track theta < 25 mrad       15029    14495    0.964469
# VetoNu0 reduced charge < 30 pC      14495    14452    0.997033
# VetoNu1 reduced charge < 30 pC      14452    14418    0.997647
#
#                                   cumulative_efficiency  efficiency_error  \
# Remove CaloNu PMT region (truth)               1.000000          0.000000
# CC events only                                 0.758073          0.000350
# nu_mu only                                     0.629807          0.000352
# In Faser Nu Box or Lead Block                  0.091786          0.000364
# Truth dec r < 100 mm                           0.039548          0.001338
# Truth pz > 100 GeV                             0.036606          0.001080
# At least one long track                        0.018970          0.002137
# Veto20 and Veto21 charge > 40 pC               0.018959          0.000145
# Timing Station Charge > 20 pC                  0.018953          0.000106
# Preshower Charge > 2.5 pC                      0.018776          0.000570
# Track pz > 100 GeV                             0.015734          0.002201
# Leading track has at >= 7 layers               0.015384          0.000962
# Track nDoF >= 9                                0.014563          0.001483
# Leading track has chi2/ndof < 15               0.014558          0.000122
# Track R at max radius < 95 mm                  0.010456          0.003051
# Track R at IFT < 95 mm                         0.010223          0.001181
# Track rVetoNu < 120 mm                         0.010064          0.001003
# Leading track theta < 25 mrad                  0.009706          0.001510
# VetoNu0 reduced charge < 30 pC                 0.009677          0.000452
# VetoNu1 reduced charge < 30 pC                 0.009655          0.000403
#
#                                   rate [events/fb/tonne]
# Remove CaloNu PMT region (truth)                       0
# CC events only                                         0
# nu_mu only                                             0
# In Faser Nu Box or Lead Block                          0
# Truth dec r < 100 mm                                   0
# Truth pz > 100 GeV                                     0
# At least one long track                                0
# Veto20 and Veto21 charge > 40 pC                       0
# Timing Station Charge > 20 pC                          0
# Preshower Charge > 2.5 pC                              0
# Track pz > 100 GeV                                     0
# Leading track has at >= 7 layers                       0
# Track nDoF >= 9                                        0
# Leading track has chi2/ndof < 15                       0
# Track R at max radius < 95 mm                          0
# Track R at IFT < 95 mm                                 0
# Track rVetoNu < 120 mm                                 0
# Leading track theta < 25 mrad                          0
# VetoNu0 reduced charge < 30 pC                         0
# VetoNu1 reduced charge < 30 pC                         0
# Cutflow for F241:
#                                       all   passed  efficiency  \
# Remove CaloNu PMT region (truth)  1450841  1450841    1.000000
# CC events only                    1450841  1100511    0.758533
# nu_mu only                        1100511   918140    0.834285
# In Faser Nu Box or Lead Block      918140   128713    0.140189
# Truth dec r < 100 mm               128713    57786    0.448952
# Truth pz > 100 GeV                  57786    53448    0.924930
# At least one long track             53448    27470    0.513957
# Veto20 and Veto21 charge > 40 pC    27470    27454    0.999418
# Timing Station Charge > 20 pC       27454    27449    0.999818
# Preshower Charge > 2.5 pC           27449    27185    0.990382
# Track pz > 100 GeV                  27185    22707    0.835277
# Leading track has at >= 7 layers    22707    22197    0.977540
# Track nDoF >= 9                     22197    20970    0.944722
# Leading track has chi2/ndof < 15    20970    20965    0.999762
# Track R at max radius < 95 mm       20965    15018    0.716337
# Track R at IFT < 95 mm              15018    14675    0.977161
# Track rVetoNu < 120 mm              14675    14455    0.985009
# Leading track theta < 25 mrad       14455    13936    0.964095
# VetoNu0 reduced charge < 30 pC      13936    13911    0.998206
# VetoNu1 reduced charge < 30 pC      13911    13871    0.997125
#
#                                   cumulative_efficiency  efficiency_error  \
# Remove CaloNu PMT region (truth)               1.000000          0.000000
# CC events only                                 0.758533          0.000355
# nu_mu only                                     0.632833          0.000354
# In Faser Nu Box or Lead Block                  0.088716          0.000362
# Truth dec r < 100 mm                           0.039829          0.001386
# Truth pz > 100 GeV                             0.036839          0.001096
# At least one long track                        0.018934          0.002162
# Veto20 and Veto21 charge > 40 pC               0.018923          0.000146
# Timing Station Charge > 20 pC                  0.018919          0.000081
# Preshower Charge > 2.5 pC                      0.018737          0.000589
# Track pz > 100 GeV                             0.015651          0.002250
# Leading track has at >= 7 layers               0.015299          0.000983
# Track nDoF >= 9                                0.014454          0.001534
# Leading track has chi2/ndof < 15               0.014450          0.000107
# Track R at max radius < 95 mm                  0.010351          0.003113
# Track R at IFT < 95 mm                         0.010115          0.001219
# Track rVetoNu < 120 mm                         0.009963          0.001003
# Leading track theta < 25 mrad                  0.009605          0.001547
# VetoNu0 reduced charge < 30 pC                 0.009588          0.000358
# VetoNu1 reduced charge < 30 pC                 0.009561          0.000454
#
#                                   rate [events/fb/tonne]
# Remove CaloNu PMT region (truth)                       0
# CC events only                                         0
# nu_mu only                                             0
# In Faser Nu Box or Lead Block                          0
# Truth dec r < 100 mm                                   0
# Truth pz > 100 GeV                                     0
# At least one long track                                0
# Veto20 and Veto21 charge > 40 pC                       0
# Timing Station Charge > 20 pC                          0
# Preshower Charge > 2.5 pC                              0
# Track pz > 100 GeV                                     0
# Leading track has at >= 7 layers                       0
# Track nDoF >= 9                                        0
# Leading track has chi2/ndof < 15                       0
# Track R at max radius < 95 mm                          0
# Track R at IFT < 95 mm                                 0
# Track rVetoNu < 120 mm                                 0
# Leading track theta < 25 mrad                          0
# VetoNu0 reduced charge < 30 pC                         0
# VetoNu1 reduced charge < 30 pC                         0
# Cutflow for Tungsten:
#                                       all   passed  efficiency  \
# Remove CaloNu PMT region (truth)  1450841  1450841    1.000000
# CC events only                    1450841  1100511    0.758533
# nu_mu only                        1100511   918140    0.834285
# In Faser Nu Box or Lead Block      918140   128713    0.140189
# Truth dec r < 100 mm               128713    57786    0.448952
# Truth pz > 100 GeV                  57786    53448    0.924930
# At least one long track             53448    27470    0.513957
# Veto20 and Veto21 charge > 40 pC    27470    27454    0.999418
# Timing Station Charge > 20 pC       27454    27449    0.999818
# Preshower Charge > 2.5 pC           27449    27185    0.990382
# Track pz > 100 GeV                  27185    22707    0.835277
# Leading track has at >= 7 layers    22707    22197    0.977540
# Track nDoF >= 9                     22197    20970    0.944722
# Leading track has chi2/ndof < 15    20970    20965    0.999762
# Track R at max radius < 95 mm       20965    15018    0.716337
# Track R at IFT < 95 mm              15018    14675    0.977161
# Track rVetoNu < 120 mm              14675    14455    0.985009
# Leading track theta < 25 mrad       14455    13936    0.964095
# VetoNu0 reduced charge < 30 pC      13936    13911    0.998206
# VetoNu1 reduced charge < 30 pC      13911    13871    0.997125
#
#                                   cumulative_efficiency  efficiency_error  \
# Remove CaloNu PMT region (truth)               1.000000          0.000000
# CC events only                                 0.758533          0.000355
# nu_mu only                                     0.632833          0.000354
# In Faser Nu Box or Lead Block                  0.088716          0.000362
# Truth dec r < 100 mm                           0.039829          0.001386
# Truth pz > 100 GeV                             0.036839          0.001096
# At least one long track                        0.018934          0.002162
# Veto20 and Veto21 charge > 40 pC               0.018923          0.000146
# Timing Station Charge > 20 pC                  0.018919          0.000081
# Preshower Charge > 2.5 pC                      0.018737          0.000589
# Track pz > 100 GeV                             0.015651          0.002250
# Leading track has at >= 7 layers               0.015299          0.000983
# Track nDoF >= 9                                0.014454          0.001534
# Leading track has chi2/ndof < 15               0.014450          0.000107
# Track R at max radius < 95 mm                  0.010351          0.003113
# Track R at IFT < 95 mm                         0.010115          0.001219
# Track rVetoNu < 120 mm                         0.009963          0.001003
# Leading track theta < 25 mrad                  0.009605          0.001547
# VetoNu0 reduced charge < 30 pC                 0.009588          0.000358
# VetoNu1 reduced charge < 30 pC                 0.009561          0.000454
#
#                                   rate [events/fb/tonne]
# Remove CaloNu PMT region (truth)                       0
# CC events only                                         0
# nu_mu only                                             0
# In Faser Nu Box or Lead Block                          0
# Truth dec r < 100 mm                                   0
# Truth pz > 100 GeV                                     0
# At least one long track                                0
# Veto20 and Veto21 charge > 40 pC                       0
# Timing Station Charge > 20 pC                          0
# Preshower Charge > 2.5 pC                              0
# Track pz > 100 GeV                                     0
# Leading track has at >= 7 layers                       0
# Track nDoF >= 9                                        0
# Leading track has chi2/ndof < 15                       0
# Track R at max radius < 95 mm                          0
# Track R at IFT < 95 mm                                 0
# Track rVetoNu < 120 mm                                 0
# Leading track theta < 25 mrad                          0
# VetoNu0 reduced charge < 30 pC                         0
# VetoNu1 reduced charge < 30 pC                         0
# Cutflow for F242:
#                                       all   passed  efficiency  \
# Remove CaloNu PMT region (truth)  1450841  1450841    1.000000
# CC events only                    1450841  1100511    0.758533
# nu_mu only                        1100511   918140    0.834285
# In Faser Nu Box or Lead Block      918140   128713    0.140189
# Truth dec r < 100 mm               128713    57786    0.448952
# Truth pz > 100 GeV                  57786    53448    0.924930
# At least one long track             53448    27470    0.513957
# Veto20 and Veto21 charge > 40 pC    27470    27454    0.999418
# Timing Station Charge > 20 pC       27454    27449    0.999818
# Preshower Charge > 2.5 pC           27449    27185    0.990382
# Track pz > 100 GeV                  27185    22707    0.835277
# Leading track has at >= 7 layers    22707    22197    0.977540
# Track nDoF >= 9                     22197    20970    0.944722
# Leading track has chi2/ndof < 15    20970    20965    0.999762
# Track R at max radius < 95 mm       20965    15018    0.716337
# Track R at IFT < 95 mm              15018    14675    0.977161
# Track rVetoNu < 120 mm              14675    14455    0.985009
# Leading track theta < 25 mrad       14455    13936    0.964095
# VetoNu0 reduced charge < 30 pC      13936    13911    0.998206
# VetoNu1 reduced charge < 30 pC      13911    13871    0.997125
#
#                                   cumulative_efficiency  efficiency_error  \
# Remove CaloNu PMT region (truth)               1.000000          0.000000
# CC events only                                 0.758533          0.000355
# nu_mu only                                     0.632833          0.000354
# In Faser Nu Box or Lead Block                  0.088716          0.000362
# Truth dec r < 100 mm                           0.039829          0.001386
# Truth pz > 100 GeV                             0.036839          0.001096
# At least one long track                        0.018934          0.002162
# Veto20 and Veto21 charge > 40 pC               0.018923          0.000146
# Timing Station Charge > 20 pC                  0.018919          0.000081
# Preshower Charge > 2.5 pC                      0.018737          0.000589
# Track pz > 100 GeV                             0.015651          0.002250
# Leading track has at >= 7 layers               0.015299          0.000983
# Track nDoF >= 9                                0.014454          0.001534
# Leading track has chi2/ndof < 15               0.014450          0.000107
# Track R at max radius < 95 mm                  0.010351          0.003113
# Track R at IFT < 95 mm                         0.010115          0.001219
# Track rVetoNu < 120 mm                         0.009963          0.001003
# Leading track theta < 25 mrad                  0.009605          0.001547
# VetoNu0 reduced charge < 30 pC                 0.009588          0.000358
# VetoNu1 reduced charge < 30 pC                 0.009561          0.000454
#
#                                   rate [events/fb/tonne]
# Remove CaloNu PMT region (truth)                       0
# CC events only                                         0
# nu_mu only                                             0
# In Faser Nu Box or Lead Block                          0
# Truth dec r < 100 mm                                   0
# Truth pz > 100 GeV                                     0
# At least one long track                                0
# Veto20 and Veto21 charge > 40 pC                       0
# Timing Station Charge > 20 pC                          0
# Preshower Charge > 2.5 pC                              0
# Track pz > 100 GeV                                     0
# Leading track has at >= 7 layers                       0
# Track nDoF >= 9                                        0
# Leading track has chi2/ndof < 15                       0
# Track R at max radius < 95 mm                          0
# Track R at IFT < 95 mm                                 0
# Track rVetoNu < 120 mm                                 0
# Leading track theta < 25 mrad                          0
# VetoNu0 reduced charge < 30 pC                         0
# VetoNu1 reduced charge < 30 pC                         0
# Cutflow for CaloNu:
#                                       all   passed  efficiency  \
# Remove CaloNu PMT region (truth)  1264895  1262287    0.997938
# CC events only                    1262287   956440    0.757704
# nu_mu only                         956440   796085    0.832342
# In Faser Nu Box or Lead Block      796085   157762    0.198172
# Truth dec r < 100 mm               157762    71534    0.453430
# Truth pz > 100 GeV                  71534    66086    0.923840
# At least one long track             66086    33710    0.510093
# Veto20 and Veto21 charge > 40 pC    33710    33693    0.999496
# Timing Station Charge > 20 pC       33693    33683    0.999703
# Preshower Charge > 2.5 pC           33683    33352    0.990173
# Track pz > 100 GeV                  33352    28051    0.841059
# Leading track has at >= 7 layers    28051    27388    0.976364
# Track nDoF >= 9                     27388    25773    0.941033
# Leading track has chi2/ndof < 15    25773    25763    0.999612
# Track R at max radius < 95 mm       25763    18439    0.715716
# Track R at IFT < 95 mm              18439    18040    0.978361
# Track rVetoNu < 120 mm              18040    17757    0.984313
# Leading track theta < 25 mrad       17757    17120    0.964127
# VetoNu0 reduced charge < 30 pC      17120    17040    0.995327
# VetoNu1 reduced charge < 30 pC      17040    16968    0.995775
#
#                                   cumulative_efficiency  efficiency_error  \
# Remove CaloNu PMT region (truth)               0.997938          0.000040
# CC events only                                 0.756142          0.000381
# nu_mu only                                     0.629368          0.000382
# In Faser Nu Box or Lead Block                  0.124723          0.000447
# Truth dec r < 100 mm                           0.056553          0.001253
# Truth pz > 100 GeV                             0.052246          0.000992
# At least one long track                        0.026650          0.001945
# Veto20 and Veto21 charge > 40 pC               0.026637          0.000122
# Timing Station Charge > 20 pC                  0.026629          0.000094
# Preshower Charge > 2.5 pC                      0.026367          0.000537
# Track pz > 100 GeV                             0.022177          0.002002
# Leading track has at >= 7 layers               0.021652          0.000907
# Track nDoF >= 9                                0.020376          0.001423
# Leading track has chi2/ndof < 15               0.020368          0.000123
# Track R at max radius < 95 mm                  0.014577          0.002810
# Track R at IFT < 95 mm                         0.014262          0.001072
# Track rVetoNu < 120 mm                         0.014038          0.000925
# Leading track theta < 25 mrad                  0.013535          0.001396
# VetoNu0 reduced charge < 30 pC                 0.013471          0.000521
# VetoNu1 reduced charge < 30 pC                 0.013415          0.000497
#
#                                   rate [events/fb/tonne]
# Remove CaloNu PMT region (truth)                       0
# CC events only                                         0
# nu_mu only                                             0
# In Faser Nu Box or Lead Block                          0
# Truth dec r < 100 mm                                   0
# Truth pz > 100 GeV                                     0
# At least one long track                                0
# Veto20 and Veto21 charge > 40 pC                       0
# Timing Station Charge > 20 pC                          0
# Preshower Charge > 2.5 pC                              0
# Track pz > 100 GeV                                     0
# Leading track has at >= 7 layers                       0
# Track nDoF >= 9                                        0
# Leading track has chi2/ndof < 15                       0
# Track R at max radius < 95 mm                          0
# Track R at IFT < 95 mm                                 0
# Track rVetoNu < 120 mm                                 0
# Leading track theta < 25 mrad                          0
# VetoNu0 reduced charge < 30 pC                         0
# VetoNu1 reduced charge < 30 pC                         0
# Cutflow for F243:
#                                       all   passed  efficiency  \
# Remove CaloNu PMT region (truth)  1450841  1450841    1.000000
# CC events only                    1450841  1100511    0.758533
# nu_mu only                        1100511   918140    0.834285
# In Faser Nu Box or Lead Block      918140   128713    0.140189
# Truth dec r < 100 mm               128713    57786    0.448952
# Truth pz > 100 GeV                  57786    53448    0.924930
# At least one long track             53448    27470    0.513957
# Veto20 and Veto21 charge > 40 pC    27470    27454    0.999418
# Timing Station Charge > 20 pC       27454    27449    0.999818
# Preshower Charge > 2.5 pC           27449    27185    0.990382
# Track pz > 100 GeV                  27185    22707    0.835277
# Leading track has at >= 7 layers    22707    22197    0.977540
# Track nDoF >= 9                     22197    20970    0.944722
# Leading track has chi2/ndof < 15    20970    20965    0.999762
# Track R at max radius < 95 mm       20965    15018    0.716337
# Track R at IFT < 95 mm              15018    14675    0.977161
# Track rVetoNu < 120 mm              14675    14455    0.985009
# Leading track theta < 25 mrad       14455    13936    0.964095
# VetoNu0 reduced charge < 30 pC      13936    13911    0.998206
# VetoNu1 reduced charge < 30 pC      13911    13871    0.997125
#
#                                   cumulative_efficiency  efficiency_error  \
# Remove CaloNu PMT region (truth)               1.000000          0.000000
# CC events only                                 0.758533          0.000355
# nu_mu only                                     0.632833          0.000354
# In Faser Nu Box or Lead Block                  0.088716          0.000362
# Truth dec r < 100 mm                           0.039829          0.001386
# Truth pz > 100 GeV                             0.036839          0.001096
# At least one long track                        0.018934          0.002162
# Veto20 and Veto21 charge > 40 pC               0.018923          0.000146
# Timing Station Charge > 20 pC                  0.018919          0.000081
# Preshower Charge > 2.5 pC                      0.018737          0.000589
# Track pz > 100 GeV                             0.015651          0.002250
# Leading track has at >= 7 layers               0.015299          0.000983
# Track nDoF >= 9                                0.014454          0.001534
# Leading track has chi2/ndof < 15               0.014450          0.000107
# Track R at max radius < 95 mm                  0.010351          0.003113
# Track R at IFT < 95 mm                         0.010115          0.001219
# Track rVetoNu < 120 mm                         0.009963          0.001003
# Leading track theta < 25 mrad                  0.009605          0.001547
# VetoNu0 reduced charge < 30 pC                 0.009588          0.000358
# VetoNu1 reduced charge < 30 pC                 0.009561          0.000454
#
#                                   rate [events/fb/tonne]
# Remove CaloNu PMT region (truth)                       0
# CC events only                                         0
# nu_mu only                                             0
# In Faser Nu Box or Lead Block                          0
# Truth dec r < 100 mm                                   0
# Truth pz > 100 GeV                                     0
# At least one long track                                0
# Veto20 and Veto21 charge > 40 pC                       0
# Timing Station Charge > 20 pC                          0
# Preshower Charge > 2.5 pC                              0
# Track pz > 100 GeV                                     0
# Leading track has at >= 7 layers                       0
# Track nDoF >= 9                                        0
# Leading track has chi2/ndof < 15                       0
# Track R at max radius < 95 mm                          0
# Track R at IFT < 95 mm                                 0
# Track rVetoNu < 120 mm                                 0
# Leading track theta < 25 mrad                          0
# VetoNu0 reduced charge < 30 pC                         0
# VetoNu1 reduced charge < 30 pC                         0

# %%
def wrap_math_text(s, caption="My table"):
    s = s.replace(r"\begin{table}", "")
    s = s.replace(r"\end{table}", "")
    s = s.replace(r"<", r"$<$").replace(r">", r"$>$").replace("=", r"$=$").replace("+", r"$+$").replace("-", r"$-$").replace("*", r"$*$").replace("/", r"$/$").replace("<=", r"$\leq$").replace(">=", r"$\geq$").replace("!=", r"$\neq$")
    s = rf"""
\begin{{table}}
\centering
\caption{{{caption}}}
\begin{{adjustbox}}{{max width=\textwidth}}
{s}
\end{{adjustbox}}
\end{{table}}
"""
    return s

# %%
with open("cutflows_all_periods.tex", 'w') as f:

    longtable = False
    float_format = "{:0.2f}".format
    colums = ["passed", "efficiency", "cumulative_efficiency", "rate [events/fb/tonne]"]

    f.write(r"\documentclass{article}" + "\n")
    f.write(r"\usepackage{graphicx}" + "\n")
    f.write(r"\usepackage{booktabs}" + "\n")
    f.write(r"\usepackage{longtable}" + "\n")
    f.write(r"\usepackage{adjustbox}" + "\n")
    f.write(r"\begin{document}" + "\n")
    t = wrap_math_text(cutflow_F222.to_latex(escape=True, columns=colums, longtable=longtable, float_format=float_format), caption="Cutflow for F222")
    f.write(t + "\n")
    t = wrap_math_text(cutflow_F223.to_latex(escape=True, columns=colums, longtable=longtable, float_format=float_format), caption="Cutflow for F223")
    f.write(t + "\n")
    t = wrap_math_text(cutflow_F231.to_latex(escape=True, columns=colums, longtable=longtable, float_format=float_format), caption="Cutflow for F231")
    f.write(t + "\n")
    t = wrap_math_text(cutflow_F232.to_latex(escape=True, columns=colums, longtable=longtable, float_format=float_format), caption="Cutflow for F232")
    f.write(t + "\n")
    t = wrap_math_text(cutflow_F241.to_latex(escape=True, columns=colums, longtable=longtable, float_format=float_format), caption="Cutflow for F241")
    f.write(t + "\n")
    t = wrap_math_text(cutflow_tungsten.to_latex(escape=True, columns=colums, longtable=longtable, float_format=float_format), caption="Cutflow for tungsten")
    f.write(t + "\n")
    t = wrap_math_text(cutflow_F242.to_latex(escape=True, columns=colums, longtable=longtable, float_format=float_format), caption="Cutflow for F242")
    f.write(t + "\n")
    t = wrap_math_text(cutflow_caloNu.to_latex(escape=True, columns=colums, longtable=longtable, float_format=float_format), caption="Cutflow for caloNu")
    f.write(t + "\n")
    t = wrap_math_text(cutflow_F243.to_latex(escape=True, columns=colums, longtable=longtable, float_format=float_format), caption="Cutflow for F243")
    f.write(t + "\n")
    f.write(r"\end{document}" + "\n")

# %%
# with open("cutflows_all_periods.tex", 'w') as f:
#     # \documentclass{article}
#     # \usepackage{graphicx} % Required for inserting images
#     # \usepackage{booktabs}
#     # \begin{document}
#     longtable = False
#     f.write(r"\documentclass{article}" + "\n")
#     f.write(r"\usepackage{graphicx}" + "\n")
#     f.write(r"\usepackage{booktabs}" + "\n")
#     f.write(r"\usepackage{longtable}" + "\n")
#     f.wr
#     f.write(r"\begin{document}" + "\n")
#     t = wrap_math_text(cutflow_F222.to_latex(escape=True, columns=["passed", "efficiency", "cumulative_efficiency"], caption="Cutflow for F222", label="tab:cutflow_F222", longtable=longtable))
#     f.write(t + "\n")
#     t = wrap_math_text(cutflow_F223.to_latex(escape=True, columns=["passed", "efficiency", "cumulative_efficiency"], caption="Cutflow for F223", label="tab:cutflow_F223", longtable=longtable))
#     f.write(t + "\n")
#     t = wrap_math_text(cutflow_F231.to_latex(escape=True, columns=["passed", "efficiency", "cumulative_efficiency"], caption="Cutflow for F231", label="tab:cutflow_F231", longtable=longtable))
#     f.write(t + "\n")
#     t = wrap_math_text(cutflow_F232.to_latex(escape=True, columns=["passed", "efficiency", "cumulative_efficiency"], caption="Cutflow for F232", label="tab:cutflow_F232", longtable=longtable))
#     f.write(t + "\n")
#     t = wrap_math_text(cutflow_F241.to_latex(escape=True, columns=["passed", "efficiency", "cumulative_efficiency"], caption="Cutflow for F241", label="tab:cutflow_F241", longtable=longtable))
#     f.write(t + "\n")
#     t = wrap_math_text(cutflow_tungsten.to_latex(escape=True, columns=["passed", "efficiency", "cumulative_efficiency"], caption="Cutflow for Tungsten", label="tab:cutflow_tungsten", longtable=longtable))
#     f.write(t + "\n")
#     t = wrap_math_text(cutflow_F242.to_latex(escape=True, columns=["passed", "efficiency", "cumulative_efficiency"], caption="Cutflow for F242", label="tab:cutflow_F242", longtable=longtable))
#     f.write(t + "\n")
#     t = wrap_math_text(cutflow_caloNu.to_latex(escape=True, columns=["passed", "efficiency", "cumulative_efficiency"], caption="Cutflow for CaloNu", label="tab:cutflow_caloNu", longtable=longtable))
#     f.write(t + "\n")
#     t = wrap_math_text(cutflow_F243.to_latex(escape=True, columns=["passed", "efficiency", "cumulative_efficiency"], caption="Cutflow for F243", label="tab:cutflow_F243", longtable=longtable))
#     f.write(t + "\n")
#     f.write(r"\end{document}" + "\n")

# %%
dfs = [cutflow_F222, cutflow_F223, cutflow_F231, cutflow_F232, cutflow_F241, cutflow_tungsten, cutflow_F242, cutflow_caloNu, cutflow_F243]
labels = ["F222", "F223", "F231", "F232", "F241", "Tungsten", "F242", "CaloNu", "F243"]
colours = ["lightcoral", "firebrick", "olive", "olivedrab", "teal", "lightblue", "steelblue", "magenta", "purple"]

fig, ax = plt.subplots(figsize=(30, 10))

n = len(dfs)
x = np.arange(len(dfs[0]))
total_width = 0.8           # Total width occupied by all bars
bar_width = total_width / n

for i, (df, label) in enumerate(zip(dfs, labels)):
    offset = (i - (n - 1) / 2) * bar_width
    ax.bar(
        x + offset,
        100 - df["efficiency"]*100,
        width=bar_width,
        label=label,
        color=colours[i]
    )
    ax.errorbar(
        x + offset,
        100 - df["efficiency"]*100,
        yerr=df["efficiency_error"]*100,
        fmt='none',
        ecolor='black',
        capsize=3,
        elinewidth=1,
        label=None
    )

ax.set_xticks(x)
ax.set_xticklabels(dfs[0].index, rotation=45, ha="right")
ax.legend()
ax.set_ylabel("Inefficiency (%)")

plt.tight_layout()
plt.savefig("cutflow_inefficiency_comparison.png", dpi=300)
plt.show()

# %%
dfs = [cutflow_F222, cutflow_F223, cutflow_F231, cutflow_F232, cutflow_F241, cutflow_tungsten, cutflow_F242, cutflow_caloNu, cutflow_F243]
labels = ["F222", "F223", "F231", "F232", "F241", "Tungsten", "F242", "CaloNu", "F243"]
fig, ax = plt.subplots(figsize=(30, 10))

n = len(dfs)
x = np.arange(len(dfs[0]))
total_width = 0.8           # Total width occupied by all bars
bar_width = total_width / n

for i, (df, label) in enumerate(zip(dfs, labels)):
    offset = (i - (n - 1) / 2) * bar_width
    ax.bar(
        x + offset,
        df["efficiency"]*100,
        width=bar_width,
        label=label,
        color=colours[i]
    )
    ax.errorbar(
        x + offset,
        df["efficiency"]*100,
        yerr=df["efficiency_error"]*100,
        fmt='none',
        ecolor='black',
        capsize=3,
        elinewidth=1,
        label=None
    )

ax.set_xticks(x)
ax.set_xticklabels(dfs[0].index, rotation=45, ha="right")
ax.legend()
ax.set_ylabel("Efficiency (%)")
# ax.set_yscale("log")

plt.tight_layout()
plt.savefig("cutflow_efficiency_comparison.png", dpi=300)
plt.show()

# %%
data = uproot.open("/home/ppd/bewilson/work/nuAnalysis/AnalysisZipFramework/submission/analysis_output/17023.root")
print(data.keys())
evt_idpass = data["eventID_pass"].arrays(library="pd")
# Out:
# ['nt;1', 'meta;1', 'cutflow;1', 'eventID_pass;2']

# %%
display(evt_idpass)
# Out:
#           passed_Colliding  passed_Trigger  passed_Good_times  \
# 0                     True            True               True
# 1                     True            True               True
# 2                     True            True               True
# 3                     True            True               True
# 4                     True            True               True
# ...                    ...             ...                ...
# 14301648              True            True               True
# 14301649              True            True               True
# 14301650             False           False               True
# 14301651              True            True               True
# 14301652              True            True               True
#
#           passed_Excluded_times  \
# 0                          True
# 1                          True
# 2                          True
# 3                          True
# 4                          True
# ...                         ...
# 14301648                   True
# 14301649                   True
# 14301650                   True
# 14301651                   True
# 14301652                   True
#
#           passed_Sanity_cut_to_remove_events_with_missing_aux_data  \
# 0                                                      True
# 1                                                      True
# 2                                                      True
# 3                                                      True
# 4                                                      True
# ...                                                     ...
# 14301648                                               True
# 14301649                                               True
# 14301650                                               True
# 14301651                                               True
# 14301652                                               True
#
#           passed_VetoNu0_reduced_charge_lt_30_pC  \
# 0                                          False
# 1                                          False
# 2                                          False
# 3                                          False
# 4                                          False
# ...                                          ...
# 14301648                                   False
# 14301649                                   False
# 14301650                                    True
# 14301651                                   False
# 14301652                                   False
#
#           passed_VetoNu1_reduced_charge_lt_30_pC  \
# 0                                          False
# 1                                          False
# 2                                          False
# 3                                          False
# 4                                          False
# ...                                          ...
# 14301648                                   False
# 14301649                                   False
# 14301650                                    True
# 14301651                                   False
# 14301652                                   False
#
#           passed_VetoNu0_raw_charge_lt_40_pC_fallback_to_raw_charge_if_reduced_charge_invalid  \
# 0                                                      True
# 1                                                      True
# 2                                                      True
# 3                                                      True
# 4                                                      True
# ...                                                     ...
# 14301648                                               True
# 14301649                                               True
# 14301650                                               True
# 14301651                                               True
# 14301652                                               True
#
#           passed_VetoNu1_raw_charge_lt_40_pC_fallback_to_raw_charge_if_reduced_charge_invalid  \
# 0                                                      True
# 1                                                      True
# 2                                                      True
# 3                                                      True
# 4                                                      True
# ...                                                     ...
# 14301648                                               True
# 14301649                                               True
# 14301650                                               True
# 14301651                                               True
# 14301652                                               True
#
#           passed_CaloNu_status_cleaning  ...  passed_Track_pz_gt_100_GeV  \
# 0                                  True  ...                        True
# 1                                  True  ...                       False
# 2                                  True  ...                       False
# 3                                  True  ...                        True
# 4                                  True  ...                        True
# ...                                 ...  ...                         ...
# 14301648                           True  ...                        True
# 14301649                           True  ...                       False
# 14301650                           True  ...                       False
# 14301651                           True  ...                        True
# 14301652                           True  ...                        True
#
#           passed_Leading_track_has_at_geq_7_layers  passed_Track_nDoF_geq_9  \
# 0                                             True                     True
# 1                                             True                     True
# 2                                             True                     True
# 3                                             True                     True
# 4                                             True                     True
# ...                                            ...                      ...
# 14301648                                      True                    False
# 14301649                                      True                     True
# 14301650                                     False                    False
# 14301651                                      True                     True
# 14301652                                      True                     True
#
#           passed_Leading_track_has_chi2_ndof_lt_15  \
# 0                                             True
# 1                                             True
# 2                                             True
# 3                                             True
# 4                                             True
# ...                                            ...
# 14301648                                      True
# 14301649                                      True
# 14301650                                     False
# 14301651                                      True
# 14301652                                      True
#
#           passed_Track_R_at_max_radius_lt_95_mm  \
# 0                                          True
# 1                                         False
# 2                                          True
# 3                                         False
# 4                                         False
# ...                                         ...
# 14301648                                   True
# 14301649                                  False
# 14301650                                   True
# 14301651                                  False
# 14301652                                  False
#
#           passed_Track_R_at_IFT_lt_95_mm  passed_Track_rVetoNu_lt_120_mm  \
# 0                                   True                            True
# 1                                  False                           False
# 2                                  False                            True
# 3                                  False                            True
# 4                                  False                           False
# ...                                  ...                             ...
# 14301648                            True                            True
# 14301649                           False                           False
# 14301650                           False                           False
# 14301651                            True                            True
# 14301652                           False                           False
#
#           passed_Leading_track_theta_lt_25_mrad    run   eventID
# 0                                          True  17023    811565
# 1                                          True  17023    811568
# 2                                          True  17023    811571
# 3                                          True  17023    811580
# 4                                          True  17023    811594
# ...                                         ...    ...       ...
# 14301648                                   True  17023  92437830
# 14301649                                   True  17023  92437832
# 14301650                                   True  17023  92437834
# 14301651                                   True  17023  92437844
# 14301652                                   True  17023  92437845
#
# [14301653 rows x 24 columns]

# %%
def get_pass_fail_counts_for_run_range(files):
    pass_fail_counts = {}

    run = os.path.basename(files[0]).split('.')[0]

    for fpath in tqdm.tqdm(files):


        with uproot.open(fpath) as f:
            tree = f["eventID_pass"]
            df = tree.arrays(library="pd")

        
            for key in df.columns:

                if "passed" not in key.lower(): continue
                
                if key not in pass_fail_counts:
                    pass_fail_counts[key] = {"pass": 0, "fail": 0}
                
                pass_fail_counts[key]["pass"] += df[key].sum()
                pass_fail_counts[key]["fail"] += len(df) - df[key].sum()

        pass_fail_counts_df = pd.DataFrame.from_dict(pass_fail_counts, orient="index")   
        # pass_fail_counts_df = pass_fail_counts_df.sort_values(by='pass', ascending=False)
        
    return pass_fail_counts_df

# %%
pass_fail_counts_F222 = get_pass_fail_counts_for_run_range(["build/MC_with_truth_cuts/2022_2023_MC.bck.root"])
pass_fail_counts_F223 = get_pass_fail_counts_for_run_range(["build/MC_with_truth_cuts/2022_2023_MC.bck.root"])
pass_fail_counts_F231 = get_pass_fail_counts_for_run_range(["build/MC_with_truth_cuts/2022_2023_MC.bck.root"])
pass_fail_counts_F232 = get_pass_fail_counts_for_run_range(["build/MC_with_truth_cuts/2022_2023_MC.bck.root"])
pass_fail_counts_F241 = get_pass_fail_counts_for_run_range(["build/MC_with_truth_cuts/2024_noCaloNu_MC.bck.root"])
pass_fail_counts_tungsten = get_pass_fail_counts_for_run_range(["build/MC_with_truth_cuts/2024_noCaloNu_MC.bck.root"])
pass_fail_counts_F242 = get_pass_fail_counts_for_run_range(["build/MC_with_truth_cuts/2024_noCaloNu_MC.bck.root"])
pass_fail_counts_caloNu = get_pass_fail_counts_for_run_range(["build/MC_with_truth_cuts/2024_withCaloNu_MC.bck.root"])
pass_fail_counts_F243 = get_pass_fail_counts_for_run_range(["build/MC_with_truth_cuts/2024_noCaloNu_MC.bck.root"])
# Out:
# 100%|██████████| 1/1 [00:01<00:00,  1.07s/it]
# 100%|██████████| 1/1 [00:00<00:00,  2.93it/s]
# 100%|██████████| 1/1 [00:00<00:00,  4.09it/s]
# 100%|██████████| 1/1 [00:00<00:00,  4.14it/s]
# 100%|██████████| 1/1 [00:01<00:00,  1.29s/it]
# 100%|██████████| 1/1 [00:00<00:00,  4.13it/s]
# 100%|██████████| 1/1 [00:00<00:00,  3.88it/s]
# 100%|██████████| 1/1 [00:00<00:00,  1.19it/s]
# 100%|██████████| 1/1 [00:00<00:00,  2.85it/s]

# %%
display(pass_fail_counts_F222)
# Out:
#                                              pass     fail
# passed_Remove_CaloNu_PMT_region_truth     1493362        0
# passed_CC_events_only                     1132078   361284
# passed_nu_mu_only                         1239953   253409
# passed_In_Faser_Nu_Box_or_Lead_Block       610434   882928
# passed_Truth_dec_r_lt_100_mm               330825  1162537
# passed_Truth_pz_gt_100_GeV                1363845   129517
# passed_VetoNu0_reduced_charge_lt_30_pC    1401870    91492
# passed_VetoNu1_reduced_charge_lt_30_pC    1389075   104287
# passed_Veto20_and_Veto21_charge_gt_40_pC   585881   907481
# passed_Timing_Station_Charge_gt_20_pC      866690   626672
# passed_Preshower_Charge_gt_2_5_pC          794410   698952
# passed_At_least_one_long_track             213156  1280206
# passed_Track_pz_gt_100_GeV                 165631  1327731
# passed_Leading_track_has_at_geq_7_layers   202496  1290866
# passed_Track_nDoF_geq_9                    190408  1302954
# passed_Leading_track_has_chi2_ndof_lt_15   208941  1284421
# passed_Track_R_at_max_radius_lt_95_mm     1376801   116561
# passed_Track_R_at_IFT_lt_95_mm             747050   746312
# passed_Track_rVetoNu_lt_120_mm             899898   593464
# passed_Leading_track_theta_lt_25_mrad     1128965   364397

# %%
dfs = [pass_fail_counts_F222, pass_fail_counts_F223, pass_fail_counts_F231, pass_fail_counts_F232, pass_fail_counts_F241, pass_fail_counts_tungsten, pass_fail_counts_F242, pass_fail_counts_caloNu, pass_fail_counts_F243]
labels = ["F222", "F223", "F231", "F232", "F241", "Tungsten", "F242", "CaloNu", "F243"]

fig, ax = plt.subplots(figsize=(30, 10))

n = len(dfs)
x = np.arange(len(dfs[0]))
total_width = 0.8           # Total width occupied by all bars
bar_width = total_width / n

for i, (df, label) in enumerate(zip(dfs, labels)):

    n_pass = df["pass"]
    n_fail = df["fail"]
    n_tot = n_pass + n_fail
    
    offset = (i - (n - 1) / 2) * bar_width
    ax.bar(
        x + offset,
        df["pass"] / (df["pass"] + df["fail"]) * 100,
        width=bar_width,
        label=label,
        color=colours[i]
    )
    ax.errorbar(
        x + offset,
        df["pass"] / (df["pass"] + df["fail"]) * 100,
        yerr=np.sqrt(1/df["pass"] + 1/df["fail"]) * 100,
        fmt='none',
        ecolor='black',
        capsize=3,
        elinewidth=1,
        label=None
    )

ax.set_xticks(x)
ax.set_xticklabels(dfs[0].index, rotation=45, ha="right")
ax.legend()
ax.set_ylabel("Fraction of events passing (%)")
# ax.set_yscale("log")
plt.tight_layout()
plt.savefig("cutflow_pass_comparison.png", dpi=300)
plt.show()

# %%
dfs = [pass_fail_counts_F222, pass_fail_counts_F223, pass_fail_counts_F231, pass_fail_counts_F232, pass_fail_counts_F241, pass_fail_counts_tungsten, pass_fail_counts_F242, pass_fail_counts_caloNu, pass_fail_counts_F243]
labels = ["F222", "F223", "F231", "F232", "F241", "Tungsten", "F242", "CaloNu", "F243"]

fig, ax = plt.subplots(figsize=(30, 10))

n = len(dfs)
x = np.arange(len(dfs[0]))
total_width = 0.8           # Total width occupied by all bars
bar_width = total_width / n

for i, (df, label) in enumerate(zip(dfs, labels)):

    n_pass = df["pass"]
    n_fail = df["fail"]
    n_tot = n_pass + n_fail
    
    offset = (i - (n - 1) / 2) * bar_width
    ax.bar(
        x + offset,
        df["fail"] / (df["pass"] + df["fail"]) * 100,
        width=bar_width,
        label=label,
        color=colours[i]
    )
    ax.errorbar(
        x + offset,
        df["fail"] / (df["pass"] + df["fail"]) * 100,
        yerr=np.sqrt(1/df["pass"] + 1/df["fail"]) * 100,
        fmt='none',
        ecolor='black',
        capsize=3,
        elinewidth=1,
        label=None
    )

ax.set_xticks(x)
ax.set_xticklabels(dfs[0].index, rotation=45, ha="right")
ax.legend()
ax.set_ylabel("Fraction of events failing (%)")
# ax.set_yscale("log")
# ax.set_ylim(1e-12, 1e3)
plt.savefig("cutflow_fail_comparison_log.png", dpi=300)
plt.tight_layout()
plt.show()

# %%
def get_cutflow_reordered(files, cutorder=None):

    run = os.path.basename(files[0]).split('.')[0]

    cutflow_dict = {}

    for fpath in tqdm.tqdm(files):

        with uproot.open(fpath) as f:
            tree = f["eventID_pass"]
            df = tree.arrays(library="pd")

            # print(df.keys())

            if cutorder is None:
                cutorder = df.columns.tolist()

            for _cut in cutorder:
                
                # cut = _cut.replace("passed_", "").replace("_", " ")
                # cut = cut.replace("gt", r"$>$").replace("lt", r"$<$").replace("geq", r"$\geq$").replace("leq", r"$\leq$").replace("ne", r"$\neq$").replace("eq", r"$=$")
                # # print(f"Cut: {cut} -> {cut_name_nice}")
                # cut = rf"{cut}"
                symbol_map = {
                    "gt": r"$>$",
                    "lt": r"$<$",
                    "geq": r"$\geq$",
                    "leq": r"$\leq$",
                    "neq": r"$\neq$",
                    "eq": r"$=$",
                }

                cut = _cut.replace("passed_", "").replace("_", " ")
                words = cut.split(" ")
                words = [symbol_map.get(w, w) for w in words]
                cut = " ".join(words)

                if cut not in cutflow_dict:
                    cutflow_dict[cut] = {}

                initial = len(df)
                df = df[df[_cut] == True]

                # print(f"Cut: {cut}, Initial: {initial}, Remaining: {len(df)}")

                cutflow_dict[cut]["passed"] = df[_cut].sum()
                cutflow_dict[cut]["failed"] = initial - len(df)
                cutflow_dict[cut]["all"] = cutflow_dict[cut]["passed"] + cutflow_dict[cut]["failed"]
                cutflow_dict[cut]["efficiency"] = cutflow_dict[cut]["passed"] / cutflow_dict[cut]["all"] if cutflow_dict[cut]["all"] > 0 else 0
                # cutflow_dict[cut]["cumulative_efficiency"] = cutflow_dict[cut]["passed"] / cutflow_dict[cutorder[0]]["all"] if cutflow_dict[cutorder[0]]["all"] > 0 else 0
                cutflow_dict[cut]["efficiency_error"] = np.sqrt(cutflow_dict[cut]["efficiency"] * (1 - cutflow_dict[cut]["efficiency"]) / cutflow_dict[cut]["all"]) if cutflow_dict[cut]["all"] > 0 else 0


    cutflow = pd.DataFrame.from_dict(cutflow_dict, orient="index")
    # cutflow["rate [events/fb/tonne]"] = cutflow["passed"] / (total_lumi * mass) if total_lumi > 0 else 0
    cutflow = cutflow.sort_values(by='passed', ascending=False)
    # cutflow["efficiency"] = cutflow["passed"] / (cutflow["passed"] + cutflow["failed"]) if (cutflow["passed"] + cutflow["failed"]) > 0 else 0
    return cutflow



cut_order = [
    # 'passed_Remove_CaloNu_PMT_region_truth', 
    'passed_CC_events_only',
    'passed_nu_mu_only', 
    'passed_In_Faser_Nu_Box_or_Lead_Block',
    'passed_Truth_dec_r_lt_100_mm', 
    'passed_Truth_pz_gt_100_GeV',
    
    'passed_Timing_Station_Charge_gt_20_pC',
    'passed_Preshower_Charge_gt_2_5_pC', 
    'passed_At_least_one_long_track',
    'passed_Track_pz_gt_100_GeV',
    'passed_Leading_track_has_at_geq_7_layers', 
    'passed_Track_nDoF_geq_9',
    'passed_Leading_track_has_chi2_ndof_lt_15',
    'passed_Track_R_at_max_radius_lt_95_mm',
    'passed_Track_R_at_IFT_lt_95_mm', 
    'passed_Track_rVetoNu_lt_120_mm',
    'passed_Leading_track_theta_lt_25_mrad',
    'passed_VetoNu0_reduced_charge_lt_30_pC',
    'passed_VetoNu1_reduced_charge_lt_30_pC',
    'passed_Veto20_and_Veto21_charge_gt_40_pC',]


cutflow_2022_2023 = get_cutflow_reordered(["build/MC_truth_back_caloNu//2022_2023.bck.root"], cutorder=cut_order)
cutflow_2024_noCaloNu = get_cutflow_reordered(["build/MC_truth_back_caloNu//2024_noCaloNu.bck.root"], cutorder=cut_order)
cutflow_2024_withCaloNu = get_cutflow_reordered(["build/MC_truth_back_caloNu//2024_CaloNu.bck.root"], cutorder=cut_order)
# Out:
# 100%|██████████| 1/1 [00:00<00:00,  2.09it/s]
# 100%|██████████| 1/1 [00:00<00:00,  2.14it/s]
# 100%|██████████| 1/1 [00:00<00:00,  2.36it/s]

# %%
dfs = [cutflow_2022_2023, cutflow_2024_noCaloNu, cutflow_2024_withCaloNu]
labels = ["2022-2023", "2024 (no CaloNu)", "2024 (with CaloNu)"]
colours = ["lightcoral", "lightblue", "magenta"]

fig, ax = plt.subplots(figsize=(30, 10))

n = len(dfs)
x = np.arange(len(dfs[0]))
total_width = 0.8           # Total width occupied by all bars
bar_width = total_width / n

for i, (df, label) in enumerate(zip(dfs, labels)):
    offset = (i - (n - 1) / 2) * bar_width
    ax.bar(
        x + offset,
        100 - df["efficiency"]*100,
        width=bar_width,
        label=label,
        color=colours[i]
    )
    ax.errorbar(
        x + offset,
        100 - df["efficiency"]*100,
        yerr=df["efficiency_error"]*100,
        fmt='none',
        ecolor='black',
        capsize=3,
        elinewidth=1,
        label=None
    )

ax.set_xticks(x)
ax.set_xticklabels(dfs[0].index, rotation=45, ha="right")
ax.legend()
ax.set_ylabel("Inefficiency (%)")

plt.tight_layout()
plt.savefig("cutflow_inefficiency_comparison.png", dpi=300)
plt.show()

# %%
dfs = [cutflow_2022_2023, cutflow_2024_noCaloNu, cutflow_2024_withCaloNu]
labels = ["2022-2023", "2024 (no CaloNu)", "2024 (with CaloNu)"]
colours = ["lightcoral", "lightblue", "violet"]


n = len(dfs)
x = np.arange(len(dfs[0]))
total_width = 0.8           # Total width occupied by all bars
bar_width = total_width / n

fig, ax = plt.subplots(figsize=(30, 10))

for i, (df, label) in enumerate(zip(dfs, labels)):
    offset = (i - (n - 1) / 2) * bar_width
    ax.bar(
        x + offset,
        df["efficiency"]*100,
        width=bar_width,
        label=label,
        color=colours[i]
    )
    ax.errorbar(
        x + offset,
        df["efficiency"]*100,
        yerr=df["efficiency_error"]*100,
        fmt='none',
        ecolor='black',
        capsize=3,
        elinewidth=1,
        label=None
    )

ax.set_xticks(x)
ax.set_xticklabels(dfs[0].index, rotation=45, ha="right")
ax.legend()
ax.set_ylabel("Efficiency (%)")
# ax.set_yscale("log")

plt.tight_layout()
plt.savefig("cutflow_efficiency_comparison.png", dpi=300)
plt.show()

# %%
cut_order = [
    'passed_Remove_CaloNu_PMT_region_truth', 
    # 'passed_CC_events_only',
    # 'passed_nu_mu_only', 
    # 'passed_In_Faser_Nu_Box_or_Lead_Block',
    # 'passed_Truth_dec_r_lt_100_mm', 
    # 'passed_Truth_pz_gt_100_GeV',
    # 'passed_Veto20_and_Veto21_charge_gt_40_pC',
    'passed_Timing_Station_Charge_gt_20_pC',
    'passed_Preshower_Charge_gt_2_5_pC', 
    'passed_At_least_one_long_track',
    'passed_Track_pz_gt_100_GeV',
    'passed_Leading_track_has_at_geq_7_layers', 
    'passed_Track_nDoF_geq_9',
    'passed_Leading_track_has_chi2_ndof_lt_15',
    'passed_Track_R_at_max_radius_lt_95_mm',
    'passed_Track_R_at_IFT_lt_95_mm', 
    'passed_Track_rVetoNu_lt_120_mm',
    'passed_Leading_track_theta_lt_25_mrad',
    'passed_Veto20_and_Veto21_charge_gt_40_pC',
    'passed_VetoNu0_reduced_charge_lt_30_pC',
    'passed_VetoNu1_reduced_charge_lt_30_pC',
    ]


cutflow_2022_2023 = get_cutflow_reordered(["build/MC_with_truth_cuts/2022_2023_MC.bck.root"], cutorder=cut_order)
cutflow_2024_noCaloNu = get_cutflow_reordered(["build/MC_with_truth_cuts/2024_noCaloNu_MC.bck.root"], cutorder=cut_order)
cutflow_2024_withCaloNu = get_cutflow_reordered(["build/MC_with_truth_cuts/2024_withCaloNu_MC.bck.root"], cutorder=cut_order)

dfs = [cutflow_2022_2023, cutflow_2024_noCaloNu, cutflow_2024_withCaloNu]
labels = ["2022-2023", "2024 (no CaloNu)", "2024 (with CaloNu)"]
colours = ["lightcoral", "lightblue", "violet"]


n = len(dfs)
x = np.arange(len(dfs[0]))
total_width = 0.8           # Total width occupied by all bars
bar_width = total_width / n

fig, ax = plt.subplots(figsize=(30, 10))

for i, (df, label) in enumerate(zip(dfs, labels)):
    offset = (i - (n - 1) / 2) * bar_width
    ax.bar(
        x + offset,
        df["efficiency"]*100,
        width=bar_width,
        label=label,
        color=colours[i]
    )
    ax.errorbar(
        x + offset,
        df["efficiency"]*100,
        yerr=df["efficiency_error"]*100,
        fmt='none',
        ecolor='black',
        capsize=3,
        elinewidth=1,
        label=None
    )

ax.set_xticks(x)
ax.set_xticklabels(dfs[0].index, rotation=45, ha="right")
ax.legend()
ax.set_ylabel("Efficiency (%)")
# ax.set_yscale("log")

plt.tight_layout()
plt.savefig("cutflow_efficiency_comparison.png", dpi=300)
plt.show()
# Out:
# 100%|██████████| 1/1 [00:00<00:00,  2.04it/s]
# 100%|██████████| 1/1 [00:00<00:00,  2.20it/s]
# 100%|██████████| 1/1 [00:00<00:00,  1.94it/s]

# %%
test = "build/MC_new_truth/2022_2023.bck.root"
test_cf = uproot.open(f"{test}:eventID_pass").arrays(library="pd")
display(test_cf)
# Out:
#          passed_Remove_CaloNu_PMT_region_truth  passed_CC_events_only  \
# 0                                         True                   True
# 1                                         True                  False
# 2                                         True                   True
# 3                                         True                   True
# 4                                         True                   True
# ...                                        ...                    ...
# 1493357                                   True                   True
# 1493358                                   True                   True
# 1493359                                   True                   True
# 1493360                                   True                   True
# 1493361                                   True                  False
#
#          passed_nu_mu_only  passed_In_Faser_Nu_Box_or_Lead_Block  \
# 0                     True                                 False
# 1                     True                                 False
# 2                     True                                 False
# 3                     True                                 False
# 4                     True                                  True
# ...                    ...                                   ...
# 1493357               True                                 False
# 1493358              False                                 False
# 1493359               True                                 False
# 1493360              False                                 False
# 1493361              False                                  True
#
#          passed_Truth_dec_r_lt_100_mm  passed_Truth_pz_gt_100_GeV  \
# 0                               False                        True
# 1                               False                        True
# 2                               False                        True
# 3                               False                        True
# 4                               False                       False
# ...                               ...                         ...
# 1493357                         False                        True
# 1493358                         False                        True
# 1493359                         False                        True
# 1493360                         False                        True
# 1493361                          True                        True
#
#          passed_At_least_one_long_track  \
# 0                                 False
# 1                                 False
# 2                                 False
# 3                                 False
# 4                                 False
# ...                                 ...
# 1493357                           False
# 1493358                           False
# 1493359                           False
# 1493360                           False
# 1493361                           False
#
#          passed_Veto20_and_Veto21_charge_gt_40_pC  \
# 0                                            True
# 1                                           False
# 2                                           False
# 3                                            True
# 4                                            True
# ...                                           ...
# 1493357                                     False
# 1493358                                     False
# 1493359                                     False
# 1493360                                     False
# 1493361                                      True
#
#          passed_Timing_Station_Charge_gt_20_pC  \
# 0                                         True
# 1                                         True
# 2                                        False
# 3                                         True
# 4                                         True
# ...                                        ...
# 1493357                                  False
# 1493358                                   True
# 1493359                                   True
# 1493360                                  False
# 1493361                                  False
#
#          passed_Preshower_Charge_gt_2_5_pC  ...  passed_Track_nDoF_geq_9  \
# 0                                    False  ...                    False
# 1                                    False  ...                    False
# 2                                    False  ...                    False
# 3                                    False  ...                    False
# 4                                    False  ...                    False
# ...                                    ...  ...                      ...
# 1493357                               True  ...                    False
# 1493358                               True  ...                    False
# 1493359                              False  ...                    False
# 1493360                               True  ...                    False
# 1493361                              False  ...                    False
#
#          passed_Leading_track_has_chi2_ndof_lt_15  \
# 0                                           False
# 1                                           False
# 2                                           False
# 3                                           False
# 4                                           False
# ...                                           ...
# 1493357                                     False
# 1493358                                     False
# 1493359                                     False
# 1493360                                     False
# 1493361                                     False
#
#          passed_Track_R_at_max_radius_lt_95_mm  \
# 0                                         True
# 1                                         True
# 2                                         True
# 3                                         True
# 4                                         True
# ...                                        ...
# 1493357                                   True
# 1493358                                   True
# 1493359                                   True
# 1493360                                   True
# 1493361                                   True
#
#          passed_Track_R_at_IFT_lt_95_mm  passed_Track_rVetoNu_lt_120_mm  \
# 0                                  True                            True
# 1                                  True                            True
# 2                                  True                            True
# 3                                  True                            True
# 4                                  True                            True
# ...                                 ...                             ...
# 1493357                           False                           False
# 1493358                           False                           False
# 1493359                           False                           False
# 1493360                           False                           False
# 1493361                           False                           False
#
#          passed_Leading_track_theta_lt_25_mrad  \
# 0                                         True
# 1                                         True
# 2                                         True
# 3                                         True
# 4                                         True
# ...                                        ...
# 1493357                                   True
# 1493358                                   True
# 1493359                                   True
# 1493360                                   True
# 1493361                                   True
#
#          passed_VetoNu0_reduced_charge_lt_30_pC  \
# 0                                         False
# 1                                          True
# 2                                          True
# 3                                          True
# 4                                          True
# ...                                         ...
# 1493357                                    True
# 1493358                                    True
# 1493359                                    True
# 1493360                                    True
# 1493361                                   False
#
#          passed_VetoNu1_reduced_charge_lt_30_pC     run  eventID
# 0                                         False  200082        0
# 1                                          True  200082        1
# 2                                          True  200082        2
# 3                                          True  200082        3
# 4                                          True  200082        4
# ...                                         ...     ...      ...
# 1493357                                    True  200089   180942
# 1493358                                    True  200089   180943
# 1493359                                    True  200089   180944
# 1493360                                    True  200089   180945
# 1493361                                   False  200089   180946
#
# [1493362 rows x 22 columns]
